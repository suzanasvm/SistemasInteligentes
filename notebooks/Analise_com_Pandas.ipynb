# %% [markdown]
# ## O que é pandas?
#
# O `pandas` é uma biblioteca muito usada para análise de dados em Python, que é [uma das linguagens de programação mais populares da atualidade](https://insights.stackoverflow.com/survey/2020#technology-programming-scripting-and-markup-languages-all-respondents). (revisado em 2020)
#
# Uma das principais vantagens de usar `Python` e o `pandas` é que você pode manipular uma quantidade relativamente grande de dados (*arquivos de até alguns GB*) com facilidade, rapidez e com infinitas possibilidades de análise, uma vez que você pode programar qualquer coisa e pegar ideias emprestadas de outras bibliotecas.
#
# ## O que vamos aprender neste jupyter notebook?
#
# Vamos aprender o básico de manipulação e visualização de dados para conseguirmos fazer por conta próprias as nossas próprias análises. A ideia é que os comandos aqui sirvam de consulta para o futuro.
#
# ## Dicas de Jupyter Notebook
#
# Este programa que estamos usando no navegado se chama Jupyter Notebook e é um interpretador de Python interativo, podemos digitar um comando de Python e apertar _Shift + Enter_ e esse comando é executado e seu resultado é impresso na tela.
#
# Existem alguns atalhos bastante úteis para trabalhar com Jupyter Notebook:
#     0. 'Esc' - Saí do modo edição da célula atual
#     1. 'Enter' - Edita a célula selecionada
#     2. 'Shift + Enter' - Executa a célula selecionada
#     3. 'A' - Adiciona uma nova célula acima da célula atual (não pode estar em modo de edição)
#     4. 'B' - Adiciona uma nova célula abaixo da célula atual (não pode estar em modo de edição)
#     5. 'X' - Deleta a célula selecionada (não pode estar em modo de edição)
#     6. 'Z' - Desfaz a deleção de uma célula (não pode estar em modo de edição)
#     7. 'Ctrl + Z' - Desfaz as últimas edições
#     8. 'Ctrl + Shift + Z' - Refaz o último comando de desfazer
#     9. 'H' - Abre um arquivo de ajuda com todos os atalhos (não pode estar em modo de edição)
#     10. 'Tab' - Faz sugestões para completar o código
#     11. '?função' - Mostra a documentação de uma dada função
#
# *(Modo de edição é quando você consegue editar uma célula, e modo de navegação é quando você não consegue)*

# %% [markdown]
# # Iniciando com Python

# %% [markdown]
# As variáveis podem conter números `int` e `float`, textos `str`, valores booleanos `bool`, entre outras.

# %%
x = 10

# %%
x
# Out:
# 10

# %%
y = 5

# %%
x + y
# Out:
# 15

# %%
nome = 'José'

# %%
sobrenome = 'da Silva'

# %%
nome_completo = nome + ' ' + sobrenome

# %%
nome_completo
# Out:
# 'José da Silva'

# %% [markdown]
# ## `Exercícios: Python Básico`

# %% [markdown]
# 1. Criar as variáveis `nome` e `idade` e atribuir valores a elas
# 2. Juntar as variáveis por meio do comando: `nome + ' ' + idade`

# %% [markdown]
# # Preparando o Ambiente
#
# Importando as bibliotecas que iremos usar no treinamento:

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Importando os dados a partir de um arquivo '<i>.csv</i>' contendo dados do IGM preparado especificamente para usarmos neste treinamento.
#
# Em nosso código esse arquivo ficará salvo com o nome de `igm`
#
# Esse arquivo foi construído a partir de uma série de colunas que compõe o IGM e também de notas do ENEM.

# %%
igm = pd.read_csv('https://raw.githubusercontent.com/suzanasvm/SistemasInteligentes/refs/heads/main/datasets/igm/igm_modificado.csv')

# %% [markdown]
# Temos uma variável chamada `igm` que está guardando algo, para descobrirmos basta digitar `igm` e apertar `Shift + Enter`:

# %% [markdown]
# # Primeiro Contato com os Dados

# %% [markdown]
# Uma das primeiras coisas a se fazer quando se pega um conjunto de dados novo é uma rápida visualização a fim de entender melhor o que tem dentro dele.

# %%
igm
# Out:
#             regiao estado                municipio  codigo_mun  capital  \
# 0          SUDESTE     SP                 ILHABELA     3520400        0
# 1          SUDESTE     SP      SANTANA DE PARNAIBA     3547304        0
# 2              SUL     SC                BOMBINHAS     4202453        0
# 3          SUDESTE     SP    SAO BERNARDO DO CAMPO     3548708        0
# 4     CENTRO-OESTE     DF                 BRASILIA     5300108        1
# ...            ...    ...                      ...         ...      ...
# 5565         NORTE     TO             RIO DOS BOIS     1718709        0
# 5566         NORTE     TO       AXIXA DO TOCANTINS     1702901        0
# 5567         NORTE     TO               FILADELFIA     1707702        0
# 5568         NORTE     TO  PONTE ALTA DO TOCANTINS     1717909        0
# 5569         NORTE     TO             SILVANOPOLIS     1720655        0
#
#                 porte  populacao      area densidade_dem           pib  ...  \
# 0     Pequeno porte 2     32,782    347.52          81.1  3.256712e+06  ...
# 1        Grande porte    129,261    179.95         604.7  7.373603e+06  ...
# 2     Pequeno porte 1     18,052     35.92           398  3.773573e+05  ...
# 3        Grande porte    822,242    409.53      1,869.40  4.766853e+07  ...
# 4        Grande porte  2,977,216  5,780.00         444.7  1.753628e+08  ...
# ...               ...        ...       ...           ...           ...  ...
# 5565  Pequeno porte 1      2,787    845.07             3  2.713671e+04  ...
# 5566  Pequeno porte 1      9,741    150.21          61.8  8.020545e+04  ...
# 5567  Pequeno porte 1      8,871  1,988.08           4.3  7.850072e+04  ...
# 5568  Pequeno porte 1      7,872  6,491.13           1.1  5.914757e+04  ...
# 5569  Pequeno porte 1      5,372  1,258.83             4  7.773486e+04  ...
#
#       gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 0               1734.52            10.63     482.054348    541.226087
# 1               1704.93            10.01     483.997625    542.760422
# 2               1370.96            10.44     472.105607    541.949533
# 3                770.79            10.22     489.241514    552.616190
# 4               2077.49             9.87     493.514758    551.982498
# ...                 ...              ...            ...           ...
# 5565                NaN             9.26     450.613333    457.100000
# 5566                NaN            10.11     437.360241    470.187952
# 5567                NaN             9.38     431.231707    456.075610
# 5568                NaN             9.07     443.876923    480.917308
# 5569                NaN            10.36     433.378571    459.132143
#
#      nota_linguagem    nota_mat  nota_redacao   idhm  ranking_igm  \
# 0        530.651111  507.952778    499.361111  0.747           1º
# 1        535.765129  499.911091    547.506655  0.885           2º
# 2        523.251923  474.506731    515.000000  0.807           3º
# 3        546.173721  514.204358    557.668055  0.864           4º
# 4        538.366612  509.206006    567.991533  0.909           5º
# ...             ...         ...           ...    ...          ...
# 5565     473.128571  458.921429    494.285714  0.413          NaN
# 5566     463.166667  442.091358    444.197531  0.439          NaN
# 5567     453.890244  426.578049    399.024390  0.425          NaN
# 5568     465.538462  437.482692    441.153846  0.432          NaN
# 5569     469.714286  407.050000    452.857143    NaN          NaN
#
#       indice_governanca
# 0                 0.767
# 1                 0.759
# 2                 0.758
# 3                 0.756
# 4                 0.736
# ...                 ...
# 5565                NaN
# 5566                NaN
# 5567                NaN
# 5568                NaN
# 5569                NaN
#
# [5570 rows x 32 columns]

# %% [markdown]
# ## Dissecando o DataFrame (Tipo de Dados)

# %% [markdown]
# Para vermos apenas uma pequena parte, temos o comando `.head()` irá mostrar por padrão as 5 primeiras linhas do que existe dentro de um conjunto de dados dentro de um objeto do pandas.

# %%
igm.head()
# Out:
#          regiao estado              municipio  codigo_mun  capital  \
# 0       SUDESTE     SP               ILHABELA     3520400        0
# 1       SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2           SUL     SC              BOMBINHAS     4202453        0
# 3       SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4  CENTRO-OESTE     DF               BRASILIA     5300108        1
#
#              porte  populacao      area densidade_dem           pib  ...  \
# 0  Pequeno porte 2     32,782    347.52          81.1  3.256712e+06  ...
# 1     Grande porte    129,261    179.95         604.7  7.373603e+06  ...
# 2  Pequeno porte 1     18,052     35.92           398  3.773573e+05  ...
# 3     Grande porte    822,242    409.53      1,869.40  4.766853e+07  ...
# 4     Grande porte  2,977,216  5,780.00         444.7  1.753628e+08  ...
#
#    gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 0            1734.52            10.63     482.054348    541.226087
# 1            1704.93            10.01     483.997625    542.760422
# 2            1370.96            10.44     472.105607    541.949533
# 3             770.79            10.22     489.241514    552.616190
# 4            2077.49             9.87     493.514758    551.982498
#
#   nota_linguagem    nota_mat  nota_redacao   idhm  ranking_igm  \
# 0     530.651111  507.952778    499.361111  0.747           1º
# 1     535.765129  499.911091    547.506655  0.885           2º
# 2     523.251923  474.506731    515.000000  0.807           3º
# 3     546.173721  514.204358    557.668055  0.864           4º
# 4     538.366612  509.206006    567.991533  0.909           5º
#
#    indice_governanca
# 0              0.767
# 1              0.759
# 2              0.758
# 3              0.756
# 4              0.736
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Outras formas de selecionar uma pequena amostra de dados:

# %% [markdown]
# O comando inverso ao `head()` é o `tail()`, que irá mostrar as 5 __últimas__ linhas do DataFrame por padrão:

# %%
igm.tail()
# Out:
#      regiao estado                municipio  codigo_mun  capital  \
# 5565  NORTE     TO             RIO DOS BOIS     1718709        0
# 5566  NORTE     TO       AXIXA DO TOCANTINS     1702901        0
# 5567  NORTE     TO               FILADELFIA     1707702        0
# 5568  NORTE     TO  PONTE ALTA DO TOCANTINS     1717909        0
# 5569  NORTE     TO             SILVANOPOLIS     1720655        0
#
#                 porte populacao      area densidade_dem       pib  ...  \
# 5565  Pequeno porte 1     2,787    845.07             3  27136.71  ...
# 5566  Pequeno porte 1     9,741    150.21          61.8  80205.45  ...
# 5567  Pequeno porte 1     8,871  1,988.08           4.3  78500.72  ...
# 5568  Pequeno porte 1     7,872  6,491.13           1.1  59147.57  ...
# 5569  Pequeno porte 1     5,372  1,258.83             4  77734.86  ...
#
#       gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 5565                NaN             9.26     450.613333    457.100000
# 5566                NaN            10.11     437.360241    470.187952
# 5567                NaN             9.38     431.231707    456.075610
# 5568                NaN             9.07     443.876923    480.917308
# 5569                NaN            10.36     433.378571    459.132143
#
#      nota_linguagem    nota_mat  nota_redacao   idhm  ranking_igm  \
# 5565     473.128571  458.921429    494.285714  0.413          NaN
# 5566     463.166667  442.091358    444.197531  0.439          NaN
# 5567     453.890244  426.578049    399.024390  0.425          NaN
# 5568     465.538462  437.482692    441.153846  0.432          NaN
# 5569     469.714286  407.050000    452.857143    NaN          NaN
#
#       indice_governanca
# 5565                NaN
# 5566                NaN
# 5567                NaN
# 5568                NaN
# 5569                NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# Apesar da convenção no Python ser utilizar o `.head()` ou o `.tail()` para olhar um DataFrame novo, algo muito mais inteligente de se fazer para ter uma ideia representativa do DataFrame é utilizar o `sample(5)`, que seleciona 5 linhas aleatórias do seu `DataFrame`. Se você executar o comando algumas vezes vai obter resultados diferentes a cada iteração.

# %%
igm.sample(5)
# Out:
#         regiao estado        municipio  codigo_mun  capital            porte  \
# 1876     NORTE     TO       DIANOPOLIS     1707009        0  Pequeno porte 2
# 2345  NORDESTE     MA           BALSAS     2101400        0      Médio porte
# 758        SUL     RS         JAGUARAO     4311007        0  Pequeno porte 2
# 2109       SUL     RS  FONTOURA XAVIER     4308300        0  Pequeno porte 1
# 2542   SUDESTE     MG       FERVEDOURO     3125952        0  Pequeno porte 1
#
#      populacao       area densidade_dem         pib  ...  gasto_pc_educacao  \
# 1876    21,457   3,217.31           5.9   297761.13  ...             556.78
# 2345    93,511  13,141.73           6.4  2513785.94  ...             753.82
# 758     28,230   2,051.02          13.6   517868.28  ...             577.93
# 2109    10,861     583.47          18.4   131531.05  ...             758.26
# 2542    10,989     357.68          28.9    87697.08  ...             411.64
#
#       exp_anos_estudo  nota_ciencias  nota_humanas nota_linguagem    nota_mat  \
# 1876             9.94     457.885882    497.362941     489.183750  458.458750
# 2345             9.55     465.185125    507.124000     492.257741  462.068147
# 758              9.62     472.085714    535.304396     529.416292  486.860112
# 2109             9.69     444.487179    490.656410     496.017949  445.800000
# 2542             8.01     447.673684    506.654386     490.833333  465.375439
#
#       nota_redacao   idhm  ranking_igm  indice_governanca
# 1876    500.868750  0.616        1877º              0.486
# 2345    497.500000  0.582        2346º              0.449
# 758     525.955056  0.630         759º              0.571
# 2109    508.205128  0.520        2110º              0.468
# 2542    514.736842  0.327        2543º              0.432
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Melhorando a visualização da tabela

# %% [markdown]
# Um truque para visualizar melhor os dados é invertendo as linhas pelas colunas (matrix transposta), para isso basta colocar um `.T` depois do nosso comando que gera uma visualização de DataFrame.

# %% [markdown]
# ## Encadeamento de funcionalidades

# %% [markdown]
# Podemos juntar diversos comando na mesma linha, isto é, logo após o `sample(5)`, pode usar o `.T`, e essas funcionalidades irão funcionar em cascata e de forma sequêncial, primeiro o `sample(5)`, e depois o `.T`

# %%
igm.sample(5).T
# Out:
#                                         630              2324  \
# regiao                          CENTRO-OESTE            NORTE
# estado                                    MS               AM
# municipio                        BRASILANDIA           UARINI
# codigo_mun                           5002308          1304260
# capital                                    0                0
# porte                        Pequeno porte 1  Pequeno porte 1
# populacao                             11,884           13,276
# area                                5,807.22        10,274.68
# densidade_dem                              2             1.20
# pib                                441477.09        106174.28
# pib_pc                              36965.34          8294.22
# participacao_transf_receita             82.0             95.0
# servidores                             762.0            279.0
# comissionados                           33.0             71.0
# comissionados_por_servidor                4%              25%
# perc_pop_econ_ativa                     1.07             0.84
# taxa_empreendedorismo                   0.17             0.46
# anos_estudo_empreendedor            7.016013         3.627148
# jornada_trabalho                   47.904188        40.837216
# gasto_pc_saude                        902.22           169.37
# hab_p_medico                      851.642857           2160.5
# exp_vida                               75.24            68.43
# gasto_pc_educacao                    1106.49          1448.73
# exp_anos_estudo                         9.85             6.94
# nota_ciencias                     447.780822          434.096
# nota_humanas                      495.316438          465.624
# nota_linguagem                    483.822535       456.398039
# nota_mat                           437.71831       424.466667
# nota_redacao                      442.253521        432.54902
# idhm                                   0.616              0.2
# ranking_igm                             631º            2325º
# indice_governanca                       0.58             0.45
#
#                                         3497                4685  \
# regiao                                   SUL             SUDESTE
# estado                                    PR                  MG
# municipio                          LINDOESTE  FELICIO DOS SANTOS
# codigo_mun                           4113452             3125408
# capital                                    0                   0
# porte                        Pequeno porte 1     Pequeno porte 1
# populacao                              5,129               5,046
# area                                  361.37              357.62
# densidade_dem                           14.8                14.4
# pib                                132482.33            36754.47
# pib_pc                              24954.29              7127.1
# participacao_transf_receita             87.0                83.0
# servidores                             227.0               148.0
# comissionados                           23.0                16.0
# comissionados_por_servidor               10%                 11%
# perc_pop_econ_ativa                     0.83                0.89
# taxa_empreendedorismo                   0.38                0.24
# anos_estudo_empreendedor            5.869335            4.441333
# jornada_trabalho                   40.944634            40.17441
# gasto_pc_saude                        808.59              663.99
# hab_p_medico                          2623.5              1706.0
# exp_vida                               71.12               72.61
# gasto_pc_educacao                     917.34              739.23
# exp_anos_estudo                        10.69                 9.3
# nota_ciencias                     471.330769          443.333333
# nota_humanas                      516.694872          491.415385
# nota_linguagem                    506.255263          492.025641
# nota_mat                          479.560526          430.274359
# nota_redacao                      502.631579          485.641026
# idhm                                     NaN               0.389
# ranking_igm                              NaN                 NaN
# indice_governanca                        NaN                 NaN
#
#                                               220
# regiao                                         SUL
# estado                                          RS
# municipio                    VISTA ALEGRE DO PRATA
# codigo_mun                                 4323606
# capital                                          0
# porte                              Pequeno porte 1
# populacao                                    1,612
# area                                        119.33
# densidade_dem                                 13.2
# pib                                       43229.95
# pib_pc                                    26784.36
# participacao_transf_receita                   86.0
# servidores                                    90.0
# comissionados                                 21.0
# comissionados_por_servidor                     23%
# perc_pop_econ_ativa                           1.41
# taxa_empreendedorismo                         0.56
# anos_estudo_empreendedor                  6.230368
# jornada_trabalho                         43.179491
# gasto_pc_saude                             1574.41
# hab_p_medico                                403.25
# exp_vida                                     75.83
# gasto_pc_educacao                           923.99
# exp_anos_estudo                                9.5
# nota_ciencias                               530.44
# nota_humanas                                595.16
# nota_linguagem                              562.24
# nota_mat                                    540.62
# nota_redacao                                 656.0
# idhm                                         0.804
# ranking_igm                                   221º
# indice_governanca                            0.625

# %% [markdown]
# ## Selecionando Linhas no pandas

# %% [markdown]
# Outra forma de vermos os 5 primeiros registros podemos usar o comando:

# %%
igm[0:5].T
# Out:
#                                            0                    1  \
# regiao                               SUDESTE              SUDESTE
# estado                                    SP                   SP
# municipio                           ILHABELA  SANTANA DE PARNAIBA
# codigo_mun                           3520400              3547304
# capital                                    0                    0
# porte                        Pequeno porte 2         Grande porte
# populacao                             32,782              129,261
# area                                  347.52               179.95
# densidade_dem                           81.1                604.7
# pib                               3256711.64           7373602.99
# pib_pc                             105112.86             60939.87
# participacao_transf_receita             77.0                 51.0
# servidores                            1495.0               6157.0
# comissionados                           74.0                587.0
# comissionados_por_servidor                5%                  10%
# perc_pop_econ_ativa                     1.18                 1.04
# taxa_empreendedorismo                   0.22                 0.25
# anos_estudo_empreendedor            8.436129            10.869492
# jornada_trabalho                   42.726231            42.542935
# gasto_pc_saude                       1529.48              1017.67
# hab_p_medico                        394.9875           400.728155
# exp_vida                               75.56                75.92
# gasto_pc_educacao                    1734.52              1704.93
# exp_anos_estudo                        10.63                10.01
# nota_ciencias                     482.054348           483.997625
# nota_humanas                      541.226087           542.760422
# nota_linguagem                    530.651111           535.765129
# nota_mat                          507.952778           499.911091
# nota_redacao                      499.361111           547.506655
# idhm                                   0.747                0.885
# ranking_igm                               1º                   2º
# indice_governanca                      0.767                0.759
#
#                                            2                      3  \
# regiao                                   SUL                SUDESTE
# estado                                    SC                     SP
# municipio                          BOMBINHAS  SAO BERNARDO DO CAMPO
# codigo_mun                           4202453                3548708
# capital                                    0                      0
# porte                        Pequeno porte 1           Grande porte
# populacao                             18,052                822,242
# area                                   35.92                 409.53
# densidade_dem                            398               1,869.40
# pib                                377357.32            47668531.31
# pib_pc                              23135.14                59149.8
# participacao_transf_receita             32.0                   49.0
# servidores                             583.0                10673.0
# comissionados                           48.0                  611.0
# comissionados_por_servidor                8%                     6%
# perc_pop_econ_ativa                     1.09                   1.09
# taxa_empreendedorismo                   0.32                   0.18
# anos_estudo_empreendedor            8.836678               9.659424
# jornada_trabalho                   40.314335              42.620522
# gasto_pc_saude                         830.7                1113.74
# hab_p_medico                     1126.466667            2459.057576
# exp_vida                               76.86                  76.65
# gasto_pc_educacao                    1370.96                 770.79
# exp_anos_estudo                        10.44                  10.22
# nota_ciencias                     472.105607             489.241514
# nota_humanas                      541.949533              552.61619
# nota_linguagem                    523.251923             546.173721
# nota_mat                          474.506731             514.204358
# nota_redacao                           515.0             557.668055
# idhm                                   0.807                  0.864
# ranking_igm                               3º                     4º
# indice_governanca                      0.758                  0.756
#
#                                         4
# regiao                       CENTRO-OESTE
# estado                                 DF
# municipio                        BRASILIA
# codigo_mun                        5300108
# capital                                 1
# porte                        Grande porte
# populacao                       2,977,216
# area                             5,780.00
# densidade_dem                       444.7
# pib                          175362791.42
# pib_pc                           62859.43
# participacao_transf_receita          35.0
# servidores                       119072.0
# comissionados                      6288.0
# comissionados_por_servidor             5%
# perc_pop_econ_ativa                   1.1
# taxa_empreendedorismo                0.18
# anos_estudo_empreendedor           9.1877
# jornada_trabalho                39.546426
# gasto_pc_saude                    1982.45
# hab_p_medico                   572.880498
# exp_vida                            77.35
# gasto_pc_educacao                 2077.49
# exp_anos_estudo                      9.87
# nota_ciencias                  493.514758
# nota_humanas                   551.982498
# nota_linguagem                 538.366612
# nota_mat                       509.206006
# nota_redacao                   567.991533
# idhm                                0.909
# ranking_igm                            5º
# indice_governanca                   0.736

# %% [markdown]
# Outra forma de vermos os cinco últimos comandos é:

# %%
igm[-5:].T
# Out:
#                                         5565                5566  \
# regiao                                 NORTE               NORTE
# estado                                    TO                  TO
# municipio                       RIO DOS BOIS  AXIXA DO TOCANTINS
# codigo_mun                           1718709             1702901
# capital                                    0                   0
# porte                        Pequeno porte 1     Pequeno porte 1
# populacao                              2,787               9,741
# area                                  845.07              150.21
# densidade_dem                              3                61.8
# pib                                 27136.71            80205.45
# pib_pc                               9995.11             8326.98
# participacao_transf_receita              NaN                 NaN
# servidores                              98.0               429.0
# comissionados                           29.0                56.0
# comissionados_por_servidor               30%                 13%
# perc_pop_econ_ativa                     0.83                0.77
# taxa_empreendedorismo                   0.23                 0.3
# anos_estudo_empreendedor            5.928716            5.406017
# jornada_trabalho                   39.776672           39.214932
# gasto_pc_saude                           NaN                 NaN
# hab_p_medico                          1370.0              1933.8
# exp_vida                               72.69                69.0
# gasto_pc_educacao                        NaN                 NaN
# exp_anos_estudo                         9.26               10.11
# nota_ciencias                     450.613333          437.360241
# nota_humanas                           457.1          470.187952
# nota_linguagem                    473.128571          463.166667
# nota_mat                          458.921429          442.091358
# nota_redacao                      494.285714          444.197531
# idhm                                   0.413               0.439
# ranking_igm                              NaN                 NaN
# indice_governanca                        NaN                 NaN
#
#                                         5567                     5568  \
# regiao                                 NORTE                    NORTE
# estado                                    TO                       TO
# municipio                         FILADELFIA  PONTE ALTA DO TOCANTINS
# codigo_mun                           1707702                  1717909
# capital                                    0                        0
# porte                        Pequeno porte 1          Pequeno porte 1
# populacao                              8,871                    7,872
# area                                1,988.08                 6,491.13
# densidade_dem                            4.3                      1.1
# pib                                 78500.72                 59147.57
# pib_pc                               8920.54                  7754.01
# participacao_transf_receita              NaN                      NaN
# servidores                             405.0                    167.0
# comissionados                          138.0                     40.0
# comissionados_por_servidor               34%                      24%
# perc_pop_econ_ativa                      0.7                     0.72
# taxa_empreendedorismo                   0.18                     0.28
# anos_estudo_empreendedor            5.519007                 6.794156
# jornada_trabalho                    33.73308                40.071482
# gasto_pc_saude                           NaN                      NaN
# hab_p_medico                     1470.666667                   3856.0
# exp_vida                               72.52                    71.72
# gasto_pc_educacao                        NaN                      NaN
# exp_anos_estudo                         9.38                     9.07
# nota_ciencias                     431.231707               443.876923
# nota_humanas                       456.07561               480.917308
# nota_linguagem                    453.890244               465.538462
# nota_mat                          426.578049               437.482692
# nota_redacao                       399.02439               441.153846
# idhm                                   0.425                    0.432
# ranking_igm                              NaN                      NaN
# indice_governanca                        NaN                      NaN
#
#                                         5569
# regiao                                 NORTE
# estado                                    TO
# municipio                       SILVANOPOLIS
# codigo_mun                           1720655
# capital                                    0
# porte                        Pequeno porte 1
# populacao                              5,372
# area                                1,258.83
# densidade_dem                              4
# pib                                 77734.86
# pib_pc                              14697.46
# participacao_transf_receita              NaN
# servidores                             150.0
# comissionados                           19.0
# comissionados_por_servidor               13%
# perc_pop_econ_ativa                     0.86
# taxa_empreendedorismo                   0.15
# anos_estudo_empreendedor            8.365326
# jornada_trabalho                   41.886471
# gasto_pc_saude                           NaN
# hab_p_medico                     1772.666667
# exp_vida                               73.84
# gasto_pc_educacao                        NaN
# exp_anos_estudo                        10.36
# nota_ciencias                     433.378571
# nota_humanas                      459.132143
# nota_linguagem                    469.714286
# nota_mat                              407.05
# nota_redacao                      452.857143
# idhm                                     NaN
# ranking_igm                              NaN
# indice_governanca                        NaN

# %% [markdown]
# A vantagem da forma explicitada acima é que podemos selecionar qualquer local da tabela, não estando restritos as primeiras linhas. Por exemplo, o comando a seguir seleciona as linhas 20 até 29:

# %%
igm[20:30].T
# Out:
#                                           20            21               22  \
# regiao                                   SUL       SUDESTE     CENTRO-OESTE
# estado                                    RS            RJ               GO
# municipio                            TUPANDI       NITEROI  CHAPADAO DO CEU
# codigo_mun                           4322251       3303302          5205471
# capital                                    0             0                0
# porte                        Pequeno porte 1  Grande porte  Pequeno porte 1
# populacao                              4,421       497,883            8,853
# area                                   59.54        133.92         2,185.12
# densidade_dem                           65.9      3,640.80              3.2
# pib                                315219.63   19908508.36        920448.16
# pib_pc                              74204.24      40284.31        114455.13
# participacao_transf_receita             83.0          44.0             69.0
# servidores                             211.0        8069.0            319.0
# comissionados                           47.0        2313.0            152.0
# comissionados_por_servidor               22%           29%              48%
# perc_pop_econ_ativa                     1.37          1.04             1.13
# taxa_empreendedorismo                   0.32          0.23             0.17
# anos_estudo_empreendedor            6.078661     11.469114         7.674727
# jornada_trabalho                   48.107082     39.660141        41.474564
# gasto_pc_saude                       1051.32        387.87          1166.68
# hab_p_medico                           430.9   1182.505967          1039.75
# exp_vida                               75.18         76.23             75.2
# gasto_pc_educacao                    1515.19        315.29          1435.33
# exp_anos_estudo                         8.73          9.68             9.45
# nota_ciencias                     489.911538    525.791393       464.187952
# nota_humanas                      557.019231    583.141027       511.890361
# nota_linguagem                       541.564    554.621886       506.293827
# nota_mat                              544.64    555.131847        484.97037
# nota_redacao                           549.6    639.916138            480.0
# idhm                                   0.656          0.94            0.714
# ranking_igm                              21º           22º              23º
# indice_governanca                      0.693         0.693            0.691
#
#                                        23               24                 25  \
# regiao                            SUDESTE              SUL            SUDESTE
# estado                                 SP               PR                 RJ
# municipio                        SOROCABA     SANTA HELENA  CASIMIRO DE ABREU
# codigo_mun                        3552205          4123501            3301306
# capital                                 0                0                  0
# porte                        Grande porte  Pequeno porte 2    Pequeno porte 2
# populacao                         652,481           25,665             41,167
# area                               450.38           758.23             460.77
# densidade_dem                    1,304.20             30.9               76.7
# pib                           26908886.58        626156.82         4068375.98
# pib_pc                           42764.72         25151.91          105694.07
# participacao_transf_receita          41.0             38.0               71.0
# servidores                        10260.0            530.0             2010.0
# comissionados                       192.0             87.0              442.0
# comissionados_por_servidor             2%              16%                22%
# perc_pop_econ_ativa                  1.05             1.16               1.07
# taxa_empreendedorismo                0.22             0.34               0.18
# anos_estudo_empreendedor         9.328404         7.527556           7.245784
# jornada_trabalho                40.241534        41.355854          43.089461
# gasto_pc_saude                     801.42            624.9            1575.51
# hab_p_medico                  1092.945111      1397.722222         555.126761
# exp_vida                            75.59            74.38              73.64
# gasto_pc_educacao                  737.82          1053.08            1088.23
# exp_anos_estudo                     10.59            10.89               9.04
# nota_ciencias                  490.120128       476.692473         475.879942
# nota_humanas                   553.714108       532.950538         533.459302
# nota_linguagem                 544.188731       520.768156         522.019062
# nota_mat                       516.983368       485.247486         484.509971
# nota_redacao                   554.441104       515.977654         549.442815
# idhm                                0.847            0.718              0.675
# ranking_igm                           24º              25º                26º
# indice_governanca                   0.691             0.69              0.689
#
#                                        26               27               28  \
# regiao                            SUDESTE              SUL          SUDESTE
# estado                                 SP               RS               SP
# municipio                        BARRETOS   CARLOS BARBOSA        BURITIZAL
# codigo_mun                        3505500          4304804          3508207
# capital                                 0                0                0
# porte                        Grande porte  Pequeno porte 2  Pequeno porte 1
# populacao                         119,948           27,835            4,377
# area                             1,566.16           229.99           266.42
# densidade_dem                        71.6            110.2             15.2
# pib                            3347124.55       1462421.26        251010.66
# pib_pc                           28418.69         54211.94         58661.06
# participacao_transf_receita          54.0             59.0             85.0
# servidores                         2751.0            418.0             98.0
# comissionados                       104.0             81.0             24.0
# comissionados_por_servidor             4%              19%              24%
# perc_pop_econ_ativa                  1.08              1.4             1.05
# taxa_empreendedorismo                 0.2             0.24             0.19
# anos_estudo_empreendedor         9.181348         7.803993         7.314732
# jornada_trabalho                41.765759        45.593353        47.127585
# gasto_pc_saude                     753.99            579.3          1055.21
# hab_p_medico                  1058.223214      1239.954545       392.090909
# exp_vida                             77.5            75.07            74.79
# gasto_pc_educacao                  735.94           694.25          1675.78
# exp_anos_estudo                     10.42            10.97            10.03
# nota_ciencias                   482.18479       502.050847       448.552632
# nota_humanas                   537.318878       548.580226       518.621053
# nota_linguagem                 526.336473       537.692982       516.510526
# nota_mat                       497.486637       533.223977       484.105263
# nota_redacao                   541.577218       550.760234       530.526316
# idhm                                0.826            0.842            0.697
# ranking_igm                           27º              28º              29º
# indice_governanca                   0.689            0.688            0.688
#
#                                           29
# regiao                          CENTRO-OESTE
# estado                                    MS
# municipio                         BATAGUASSU
# codigo_mun                           5001904
# capital                                    0
# porte                        Pequeno porte 2
# populacao                             22,084
# area                                2,417.60
# densidade_dem                            8.2
# pib                                492873.37
# pib_pc                              23312.52
# participacao_transf_receita             61.0
# servidores                             493.0
# comissionados                           39.0
# comissionados_por_servidor                8%
# perc_pop_econ_ativa                     1.05
# taxa_empreendedorismo                   0.19
# anos_estudo_empreendedor            7.008062
# jornada_trabalho                   43.665268
# gasto_pc_saude                        664.85
# hab_p_medico                     1788.583333
# exp_vida                                75.8
# gasto_pc_educacao                     745.24
# exp_anos_estudo                         9.82
# nota_ciencias                      455.68314
# nota_humanas                      506.393605
# nota_linguagem                    496.972024
# nota_mat                          457.501786
# nota_redacao                      493.095238
# idhm                                   0.637
# ranking_igm                              30º
# indice_governanca                      0.685

# %% [markdown]
# ## Slicing no Pandas

# %% [markdown]
# O nome dessa operação de colocar algo entre colchetes é slicing, e isso como convenção geral é uma forma de selecionar um subconjunto de dados.

# %% [markdown]
# [20:30] vai selecionar exatamente 10 elementos (30 - 20). O número da direita menos o número da esquerda é sempre o total de elementos que serão selecionados, e isso é uma convenção no Python.
#
# O número 20 é selecionado por ser um intervalo fechado na esquerda, e o número 30 não é selecionado por ser um intervalo aberto na direita. O que é outra convenção do Python.

# %% [markdown]
# ## Selecionando colunas

# %% [markdown]
# Para selecionarmos colunas no pandas, basta dizermos o nome do DataFrame seguido por colchetes com o nome da coluna dentro:
#
# __Nome do Dataframe:__ `igm`
#
# __Colchetes com a coluna dentro:__ `['Porte do Município']`
#
# __Comando completo:__ `igm['Porte do Município']`

# %%
igm['porte']
# Out:
# 0       Pequeno porte 2
# 1          Grande porte
# 2       Pequeno porte 1
# 3          Grande porte
# 4          Grande porte
#              ...
# 5565    Pequeno porte 1
# 5566    Pequeno porte 1
# 5567    Pequeno porte 1
# 5568    Pequeno porte 1
# 5569    Pequeno porte 1
# Name: porte, Length: 5570, dtype: object

# %% [markdown]
# ## Selecionando Múltiplas Colunas

# %% [markdown]
# Podemos selecionar multiplas colunas com o comando `igm[['municipio', 'indice_governanca']]`:

# %%
igm[['municipio', 'indice_governanca']]
# Out:
#                     municipio  indice_governanca
# 0                    ILHABELA              0.767
# 1         SANTANA DE PARNAIBA              0.759
# 2                   BOMBINHAS              0.758
# 3       SAO BERNARDO DO CAMPO              0.756
# 4                    BRASILIA              0.736
# ...                       ...                ...
# 5565             RIO DOS BOIS                NaN
# 5566       AXIXA DO TOCANTINS                NaN
# 5567               FILADELFIA                NaN
# 5568  PONTE ALTA DO TOCANTINS                NaN
# 5569             SILVANOPOLIS                NaN
#
# [5570 rows x 2 columns]

# %% [markdown]
# ##  `Exercícios: Seleções Básicas`

# %% [markdown]
# 1. Selecionar as 10 primeiras linhas mostrando as colunas `municipio`, `estado` e `idhm`.
# 2. Selecionar das linhas 15 a 24 os valores da coluna `municipio`

# %% [markdown]
# # Fazendo Operações de Agregamento:

# %% [markdown]
# Vamos contar quantos valores da coluna `porte` temos para cada tipo com o comando `value_counts()`, trazendo os valores ABSOLUTOS:

# %%
igm['porte'].value_counts()
# Out:
# porte
# Pequeno porte 1    3810
# Pequeno porte 2    1101
# Médio porte         350
# Grande porte        309
# Name: count, dtype: int64

# %% [markdown]
# Também podemos observar os valores relativos, ou seja, em porcentagem, passando o parametro normalize=True

# %%
igm['porte'].value_counts(normalize=True)
# Out:
# porte
# Pequeno porte 1    0.684022
# Pequeno porte 2    0.197666
# Médio porte        0.062837
# Grande porte       0.055476
# Name: proportion, dtype: float64

# %% [markdown]
# Observe que por padrão o pandas considera 100% como 1, podemos melhora a visualização com a seguinte alteração

# %%
igm['porte'].value_counts(normalize=True)*100
# Out:
# porte
# Pequeno porte 1    68.402154
# Pequeno porte 2    19.766607
# Médio porte         6.283662
# Grande porte        5.547576
# Name: proportion, dtype: float64

# %% [markdown]
# ## Plotando Nosso Primeiro Gráfico

# %% [markdown]
# Para garantir que nossos gráficos vão ser plotados em todas as versões do `Jupyter Notebook` precisamos rodar o comando abaixo:

# %%
# %matplotlib inline

# %% [markdown]
# Com bastante facilidade podemos plotar um gráfico com os valores acima, basta colocar `.plot.bar()` na sequência.

# %%
igm['porte'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='porte'>

# %% [markdown]
# ##  `Exercícios: Series`

# %% [markdown]
# 1. Contar o número de munícipios por estado
# 2. Plotar gráfico de número de munícipios por estado

# %% [markdown]
# ## Operações de Agregamento Numéricas

# %% [markdown]
# Vamos criar uma variável chamada `ind_des` para guarda a nossa `Series` relativa a coluna `indice_governanca`

# %%
ind_des = igm['indice_governanca']

# %% [markdown]
# Vamos contar a quantidade de elementos em `ind_des`

# %% [markdown]
# Para verificarmos quais são os valores em branco podemos usar o `isnull()`, que nos retornar uma `Series` com valores `True` ou `False` de acordo com se os valores estiverem em branco ou não.

# %%
ind_des.count()
# Out:
# 3303

# %% [markdown]
# Note que o `.count()` não contabiliza valores em branco, se quisermos ver os valores em branco temos que usar o atributo `.size`, que não tem paranteses

# %%
ind_des.size
# Out:
# 5570

# %%
ind_des.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5565     True
# 5566     True
# 5567     True
# 5568     True
# 5569     True
# Name: indice_governanca, Length: 5570, dtype: bool

# %% [markdown]
# Uma forma de melhor utilizarmos essa informação é contabilizando o total de valores em branco, note que `True` tem valor `1` e `False` tem valor `0`, portanto se somarmos todos os elementos, teremos o total de valores em branco.

# %%
ind_des.isnull().sum()
# Out:
# 2267

# %% [markdown]
# Podemos remover esses valores em branco com um simples comando, o `dropna()`.

# %%
ind_des.dropna()
# Out:
# 0       0.767
# 1       0.759
# 2       0.758
# 3       0.756
# 4       0.736
#         ...
# 3298    0.296
# 3299    0.282
# 3300    0.279
# 3301    0.278
# 3302    0.258
# Name: indice_governanca, Length: 3303, dtype: float64

# %% [markdown]
# Ele retornou os valores, e podemos ver que não tem nenhum valor em branco, mas vamos verificar de fato para ver se mudamos os nossos valores:

# %%
ind_des.isnull().sum()
# Out:
# 2267

# %% [markdown]
# Não mudou, por que isso aconteceu? Uma série de funções no pandas não alteram o objeto em questão, porque muitas vezes estamos fazendo transformações temporárias para gerar uma visualização ou análise, para mudar o objeto temos que passar um parâmetro a mais que é o `inplace=True`.

# %%
ind_des.dropna(inplace=True)

# %% [markdown]
# Vamos verificar novamente se temos valores em branco no nosso conjunto de dados:

# %%
ind_des.isnull().sum()
# Out:
# 0

# %% [markdown]
# Selecionando o valor mínimo do índice de desempenho

# %%
ind_des.min()
# Out:
# 0.258

# %% [markdown]
# Selecionando o valor máximo do índice de desempenho

# %%
ind_des.max()
# Out:
# 0.767

# %% [markdown]
# Olhando a média dos valores:

# %%
ind_des.mean()
# Out:
# 0.5019585225552529

# %% [markdown]
# Olhando o desvio padrão dos valores:

# %%
ind_des.std()
# Out:
# 0.08370404317359423

# %% [markdown]
# ## Tendo uma visão geral do Índice de Governança

# %% [markdown]
# Um comando muito útil para avaliar uma `Series` é o `.describe()`, que irá calcular os quartis, valores máximo, mínimo, a média e o desvio padrão.

# %%
ind_des.describe()
# Out:
# count    3303.000000
# mean        0.501959
# std         0.083704
# min         0.258000
# 25%         0.438000
# 50%         0.504000
# 75%         0.566000
# max         0.767000
# Name: indice_governanca, dtype: float64

# %% [markdown]
# ## Usando o .describe() em um DataFrame

# %% [markdown]
# O bom é que o `describe()` também funciona em um `DataFrame`, e por padrão apenas para as colunas numéricas:

# %%
igm.describe()
# Out:
#          codigo_mun      capital           pib         pib_pc  \
# count  5.570000e+03  5570.000000  5.570000e+03    5570.000000
# mean   3.253591e+06     0.004847  9.544801e+05   17374.483108
# std    9.849103e+05     0.069461  9.502661e+06   20133.341193
# min    1.100015e+06     0.000000  9.678440e+03    3241.290000
# 25%    2.512126e+06     0.000000  5.922529e+04    7077.357500
# 50%    3.146280e+06     0.000000  1.301531e+05   12621.810000
# 75%    4.119190e+06     0.000000  3.426808e+05   21262.387500
# max    5.300108e+06     1.000000  5.707062e+08  715193.700000
#
#        participacao_transf_receita     servidores  comissionados  \
# count                  4893.000000    5233.000000    5570.000000
# mean                     82.316575     771.324861      96.371275
# std                      11.272136    3209.755931     234.994469
# min                       0.000000       1.000000       0.000000
# 25%                      77.000000     190.000000      24.000000
# 50%                      85.000000     329.000000      45.000000
# 75%                      91.000000     663.000000      92.000000
# max                     100.000000  134273.000000    7240.000000
#
#        perc_pop_econ_ativa  taxa_empreendedorismo  anos_estudo_empreendedor  \
# count          5565.000000            5570.000000               5570.000000
# mean              0.936503               0.250939                  6.124378
# std               0.178640               0.098014                  1.462946
# min               0.290000               0.000000                  0.000000
# 25%               0.810000               0.190000                  5.039926
# 50%               0.940000               0.230000                  6.049990
# 75%               1.050000               0.290000                  7.175247
# max               1.640000               0.770000                 11.553164
#
#        ...     exp_vida  gasto_pc_educacao  exp_anos_estudo  nota_ciencias  \
# count  ...  5565.000000        4880.000000      5565.000000    5558.000000
# mean   ...    73.088996         769.775533         9.463639     460.124417
# std    ...     2.680715         277.841845         1.098269      19.275298
# min    ...    65.300000          56.600000         4.340000     385.000000
# 25%    ...    71.150000         585.892500         8.750000     446.324306
# 50%    ...    73.470000         731.825000         9.470000     457.549922
# 75%    ...    75.160000         898.625000        10.210000     471.752760
# max    ...    78.640000        3695.930000        12.830000     550.566667
#
#        nota_humanas  nota_linguagem     nota_mat  nota_redacao         idhm  \
# count   5558.000000     5557.000000  5557.000000   5557.000000  4986.000000
# mean     509.526944      499.286922   465.007784    501.840952     0.518626
# std       23.816077       22.056169    28.496300     44.904955     0.171847
# min      373.800000      404.000000   369.275000    320.000000     0.000000
# 25%      492.975737      483.454286   443.078082    473.125000     0.375000
# 50%      508.987016      499.105769   461.261538    502.406015     0.535000
# 75%      526.405985      515.125917   483.773196    532.173913     0.659000
# max      595.160000      571.659503   603.415000    668.000000     1.000000
#
#        indice_governanca
# count        3303.000000
# mean            0.501959
# std             0.083704
# min             0.258000
# 25%             0.438000
# 50%             0.504000
# 75%             0.566000
# max             0.767000
#
# [8 rows x 23 columns]

# %% [markdown]
# ##  `Exercícios: Agregações Númericas`

# %% [markdown]
# 1. Utilize o `.min()`, `.max()`, e `.mean()` para avaliar os dados da coluna `exp_vida`
# 2. Utilize o `.describe()` para avaliar os dados da coluna `idhm`

# %% [markdown]
# ## Plotando um Histograma do Índice de Governança

# %%
ind_des.hist()
# Out:
# <Axes: >

# %% [markdown]
# # Primeiros Gráficos com o Seaborn
#
# O Python tem diversas ferramentas para plotar gráficos, uma das mais fáceis e poderosas de usar é o __seaborn__ que foi importado no começo do nosso código com o comando <i>import seaborn as sns</i>.

# %%
sns.kdeplot(ind_des)
# Out:
# <Axes: xlabel='indice_governanca', ylabel='Density'>

# %% [markdown]
# Um gráfico ligeiramente diferente, mas que a além da linha plota as `bins` do histograma.

# %%
sns.distplot(ind_des.dropna())
# Out:
# /tmp/ipykernel_60906/4087297351.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='indice_governanca', ylabel='Density'>

# %% [markdown]
# ##  `Exercícios: Histogramas`

# %% [markdown]
# 1. Plote um histograma do `gasto_pc_educacao`
# 2. Plote um `sns.kdeplot()` do `gasto_pc_educacao`
# 3. Plote um `sns.distplot()` do `gasto_pc_educacao`
# 4. Utilize o `.describe()` para ver os valores numéricos do `gasto_pc_educacao`

# %% [markdown]
# ## Fazendo Filtros

# %% [markdown]
# Tem alguns jeitos de selecionar subconjuntos, podemos escolher todas as cidades que pertençam a região nordeste utilizando o comando abaixo:

# %%
igm[igm['regiao']=='NORDESTE']
# Out:
#         regiao estado                 municipio  codigo_mun  capital  \
# 67    NORDESTE     PE                   IPOJUCA     2607208        0
# 77    NORDESTE     CE                 FORTALEZA     2304400        1
# 236   NORDESTE     BA          MATA DE SAO JOAO     2921005        0
# 241   NORDESTE     PB               JOAO PESSOA     2507507        1
# 261   NORDESTE     CE                   EUSEBIO     2304285        0
# ...        ...    ...                       ...         ...      ...
# 5245  NORDESTE     SE              SAO DOMINGOS     2806800        0
# 5246  NORDESTE     SE         CEDRO DE SAO JOAO     2801603        0
# 5247  NORDESTE     SE                POCO VERDE     2805505        0
# 5248  NORDESTE     SE  NOSSA SENHORA DE LOURDES     2804706        0
# 5249  NORDESTE     SE                     ITABI     2803104        0
#
#                 porte  populacao    area densidade_dem          pib  ...  \
# 67        Médio porte     92,965  527.11           153   8411558.28  ...
# 77       Grande porte  2,609,716  314.93      7,786.40  49745920.35  ...
# 236   Pequeno porte 2     46,392   633.2          63.5    981822.66  ...
# 241      Grande porte    801,718  211.48      3,421.30  14841805.03  ...
# 261       Médio porte     51,913   79.01         582.7   2077064.42  ...
# ...               ...        ...     ...           ...          ...  ...
# 5245  Pequeno porte 1     11,053     102         100.2     93161.64  ...
# 5246  Pequeno porte 1      5,912   83.71          67.3     38902.98  ...
# 5247  Pequeno porte 2     23,580  439.84            50    185982.88  ...
# 5248  Pequeno porte 1      6,512   81.06            77     48201.34  ...
# 5249  Pequeno porte 1      5,002  184.42            27     38696.88  ...
#
#       gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 67              1779.61             8.65     463.458278    505.182119
# 77               382.80            10.04     492.416843    542.762946
# 236             1232.37             8.65     448.619011    508.202281
# 241              428.25             9.87     497.310587    548.607283
# 261             1112.71            10.13     479.490850    521.400000
# ...                 ...              ...            ...           ...
# 5245             686.34             9.06     465.242000    501.113000
# 5246             613.36             9.08     461.052381    509.559524
# 5247             645.33             8.98     463.451337    506.520321
# 5248                NaN             9.30     445.827184    500.052427
# 5249                NaN             9.91     468.687805    494.790244
#
#      nota_linguagem    nota_mat  nota_redacao   idhm  ranking_igm  \
# 67       503.076629  449.237753    480.988764  0.420          68º
# 77       525.144742  500.962286    574.679852  0.742          78º
# 236      493.710305  442.017176    472.366412  0.537         237º
# 241      529.736787  507.429430    594.096408  0.764         242º
# 261      507.040535  480.173051    515.209354  0.616         262º
# ...             ...         ...           ...    ...          ...
# 5245     485.569697  459.546465    517.979798  0.346          NaN
# 5246     487.254762  442.495238    578.571429  0.430          NaN
# 5247     496.670430  453.449462    529.677419    NaN          NaN
# 5248     485.945098  441.245098    475.882353  0.370          NaN
# 5249     500.912195  469.095122    488.780488    NaN          NaN
#
#       indice_governanca
# 67                0.659
# 77                0.656
# 236               0.622
# 241               0.622
# 261               0.619
# ...                 ...
# 5245                NaN
# 5246                NaN
# 5247                NaN
# 5248                NaN
# 5249                NaN
#
# [1794 rows x 32 columns]

# %% [markdown]
# Quando rodamos o comando _igm['Região']=='NORDESTE'_ temos um resultado (em forma de Series) de _True_ (Verdadeiro) ou _False_ (Falso) de acordo com o índice do elemento.

# %%
igm['regiao']=='NORDESTE'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5565    False
# 5566    False
# 5567    False
# 5568    False
# 5569    False
# Name: regiao, Length: 5570, dtype: bool

# %% [markdown]
# Podemos guardar esse resultado dentro de uma variável:

# %%
filtro = igm['regiao']=='NORDESTE'

# %% [markdown]
# E executar o filtro em seguida:

# %%
igm[filtro].T
# Out:
#                                     67            77                236   \
# regiao                          NORDESTE      NORDESTE          NORDESTE
# estado                                PE            CE                BA
# municipio                        IPOJUCA     FORTALEZA  MATA DE SAO JOAO
# codigo_mun                       2607208       2304400           2921005
# capital                                0             1                 0
# porte                        Médio porte  Grande porte   Pequeno porte 2
# populacao                         92,965     2,609,716            46,392
# area                              527.11        314.93             633.2
# densidade_dem                        153      7,786.40              63.5
# pib                           8411558.28   49745920.35         981822.66
# pib_pc                          95666.34       19494.4          22044.61
# participacao_transf_receita         67.0          53.0              51.0
# servidores                        2662.0       27093.0            1200.0
# comissionados                     1907.0        2201.0             458.0
# comissionados_por_servidor           72%            8%               38%
# perc_pop_econ_ativa                 0.82           1.0              0.88
# taxa_empreendedorismo               0.16          0.22               0.2
# anos_estudo_empreendedor        6.346311      8.579938          7.803896
# jornada_trabalho               43.826898     39.916316         38.495069
# gasto_pc_saude                   1208.11        620.43            602.14
# hab_p_medico                   521.27907           NaN             766.0
# exp_vida                           71.44         74.41             74.09
# gasto_pc_educacao                1779.61         382.8           1232.37
# exp_anos_estudo                     8.65         10.04              8.65
# nota_ciencias                 463.458278    492.416843        448.619011
# nota_humanas                  505.182119    542.762946        508.202281
# nota_linguagem                503.076629    525.144742        493.710305
# nota_mat                      449.237753    500.962286        442.017176
# nota_redacao                  480.988764    574.679852        472.366412
# idhm                                0.42         0.742             0.537
# ranking_igm                          68º           78º              237º
# indice_governanca                  0.659         0.656             0.622
#
#                                      241          261           308   \
# regiao                           NORDESTE     NORDESTE      NORDESTE
# estado                                 PB           CE            PI
# municipio                     JOAO PESSOA      EUSEBIO      TERESINA
# codigo_mun                        2507507      2304285       2211001
# capital                                 1            0             1
# porte                        Grande porte  Médio porte  Grande porte
# populacao                         801,718       51,913       847,430
# area                               211.48        79.01      1,391.98
# densidade_dem                    3,421.30        582.7         584.9
# pib                           14841805.03   2077064.42   14803635.19
# pib_pc                           19284.91     41999.08      17697.64
# participacao_transf_receita          64.0         55.0          63.0
# servidores                         9668.0       1351.0       13333.0
# comissionados                      1142.0        629.0        1767.0
# comissionados_por_servidor            12%          47%           13%
# perc_pop_econ_ativa                  0.99         0.94          1.01
# taxa_empreendedorismo                0.13         0.18          0.22
# anos_estudo_empreendedor         5.344429     7.775028      8.048559
# jornada_trabalho                35.112496    38.457155     39.555976
# gasto_pc_saude                     486.34       926.89        954.24
# hab_p_medico                    617.18419    393.03125   2374.576271
# exp_vida                            74.89        72.66         74.22
# gasto_pc_educacao                  428.25      1112.71        445.35
# exp_anos_estudo                      9.87        10.13         10.36
# nota_ciencias                  497.310587    479.49085    488.519135
# nota_humanas                   548.607283        521.4    535.159021
# nota_linguagem                 529.736787   507.040535    518.538822
# nota_mat                        507.42943   480.173051    494.811399
# nota_redacao                   594.096408   515.209354    556.543246
# idhm                                0.764        0.616         0.735
# ranking_igm                          242º         262º          309º
# indice_governanca                   0.622        0.619         0.613
#
#                                      319           354           396   \
# regiao                           NORDESTE      NORDESTE      NORDESTE
# estado                                 SE            BA            PE
# municipio                         ARACAJU      SALVADOR        RECIFE
# codigo_mun                        2800308       2927408       2611606
# capital                                 1             1             1
# porte                        Grande porte  Grande porte  Grande porte
# populacao                         641,523     2,938,092     1,625,583
# area                               181.86        692.82        218.44
# densidade_dem                    3,140.70      3,859.40      7,039.60
# pib                            13918123.9    52667933.2   46445339.29
# pib_pc                           22646.67      18264.13      29037.18
# participacao_transf_receita          54.0          47.0          48.0
# servidores                         7653.0       21057.0       19545.0
# comissionados                      2528.0         794.0        2003.0
# comissionados_por_servidor            33%            4%           10%
# perc_pop_econ_ativa                   1.0          1.08          0.99
# taxa_empreendedorismo                0.22           0.2          0.22
# anos_estudo_empreendedor         9.151685       9.07786       9.28345
# jornada_trabalho                38.950234     38.236924     39.300897
# gasto_pc_saude                     768.29        383.66        546.36
# hab_p_medico                  1275.595092   4425.193598   1099.444976
# exp_vida                            74.36          75.1          74.5
# gasto_pc_educacao                  241.69        341.46        451.58
# exp_anos_estudo                      9.76          9.16          9.53
# nota_ciencias                  510.013263    489.200664    501.293359
# nota_humanas                   556.423645    543.699326    552.167903
# nota_linguagem                  530.96594    524.977091    535.672549
# nota_mat                       516.897407    493.592942    515.279644
# nota_redacao                   604.460357    558.132535    585.963751
# idhm                                 0.78         0.754         0.785
# ranking_igm                          320º          355º          397º
# indice_governanca                   0.611         0.607         0.602
#
#                                         404   ...             5240  \
# regiao                              NORDESTE  ...         NORDESTE
# estado                                    BA  ...               SE
# municipio                           MAETINGA  ...     BREJO GRANDE
# codigo_mun                           2919959  ...          2800704
# capital                                    0  ...                0
# porte                        Pequeno porte 1  ...  Pequeno porte 1
# populacao                              4,796  ...            8,271
# area                                  630.08  ...           148.86
# densidade_dem                           10.3  ...               52
# pib                                 35932.78  ...         67495.71
# pib_pc                               6016.88  ...          8322.53
# participacao_transf_receita             61.0  ...             93.0
# servidores                             212.0  ...            118.0
# comissionados                           52.0  ...             65.0
# comissionados_por_servidor               25%  ...              55%
# perc_pop_econ_ativa                     0.98  ...             0.79
# taxa_empreendedorismo                   0.11  ...              0.6
# anos_estudo_empreendedor            5.034949  ...         3.952843
# jornada_trabalho                   34.381214  ...         30.98164
# gasto_pc_saude                       1206.47  ...           365.77
# hab_p_medico                      370.733333  ...      2721.666667
# exp_vida                               70.07  ...            67.03
# gasto_pc_educacao                    1531.39  ...           796.93
# exp_anos_estudo                         8.53  ...              8.7
# nota_ciencias                     444.812903  ...       436.808889
# nota_humanas                      493.232258  ...       467.111111
# nota_linguagem                    504.196774  ...       451.513953
# nota_mat                          445.374194  ...       417.872093
# nota_redacao                      516.774194  ...       395.813953
# idhm                                   0.227  ...            0.232
# ranking_igm                             405º  ...              NaN
# indice_governanca                      0.601  ...              NaN
#
#                                           5241             5242  \
# regiao                                NORDESTE         NORDESTE
# estado                                      SE               SE
# municipio                    RIACHAO DO DANTAS          SALGADO
# codigo_mun                             2805802          2806206
# capital                                      0                0
# porte                          Pequeno porte 1  Pequeno porte 2
# populacao                               19,995           20,126
# area                                     531.7           247.58
# densidade_dem                             36.5             78.1
# pib                                  154649.21        150036.74
# pib_pc                                 7756.89          7504.09
# participacao_transf_receita               95.0             89.0
# servidores                               589.0            747.0
# comissionados                             76.0            113.0
# comissionados_por_servidor                 13%              15%
# perc_pop_econ_ativa                       0.72             0.89
# taxa_empreendedorismo                     0.39             0.24
# anos_estudo_empreendedor              4.068861         4.644835
# jornada_trabalho                     29.645215        36.452003
# gasto_pc_saude                          331.38           390.79
# hab_p_medico                         1247.3125      1431.357143
# exp_vida                                 71.87            72.35
# gasto_pc_educacao                       930.64           849.94
# exp_anos_estudo                           8.29             8.83
# nota_ciencias                       445.406731       465.055769
# nota_humanas                          488.1875            513.4
# nota_linguagem                      482.058824          488.904
# nota_mat                             436.62451          463.699
# nota_redacao                        496.078431            521.0
# idhm                                     0.229            0.396
# ranking_igm                                NaN              NaN
# indice_governanca                          NaN              NaN
#
#                                         5243         5244             5245  \
# regiao                              NORDESTE     NORDESTE         NORDESTE
# estado                                    SE           SE               SE
# municipio                             CAPELA    ITABAIANA     SAO DOMINGOS
# codigo_mun                           2801306      2802908          2806800
# capital                                    0            0                0
# porte                        Pequeno porte 2  Médio porte  Pequeno porte 1
# populacao                             33,715       94,393           11,053
# area                                  442.46       335.76              102
# densidade_dem                           69.5        258.3            100.2
# pib                                265038.67   1265104.06         93161.64
# pib_pc                               8113.59     13770.14          8625.28
# participacao_transf_receita             83.0         84.0             97.0
# servidores                             759.0       1799.0            265.0
# comissionados                           75.0        227.0            120.0
# comissionados_por_servidor               10%          13%              45%
# perc_pop_econ_ativa                     0.73         0.97             1.02
# taxa_empreendedorismo                   0.18          0.4             0.27
# anos_estudo_empreendedor            5.960935     5.091843          4.72577
# jornada_trabalho                   37.534597    39.621078        32.120295
# gasto_pc_saude                        153.45       344.28           319.32
# hab_p_medico                          2064.0  1749.660377           2177.4
# exp_vida                               70.97        73.03            70.36
# gasto_pc_educacao                     764.96       439.65           686.34
# exp_anos_estudo                         9.15         8.98             9.06
# nota_ciencias                        450.125   499.352113          465.242
# nota_humanas                      490.450455   546.236186          501.113
# nota_linguagem                    480.786175   522.756236       485.569697
# nota_mat                          438.641475   501.290263       459.546465
# nota_redacao                      481.474654   611.137856       517.979798
# idhm                                   0.411        0.475            0.346
# ranking_igm                              NaN          NaN              NaN
# indice_governanca                        NaN          NaN              NaN
#
#                                           5246             5247  \
# regiao                                NORDESTE         NORDESTE
# estado                                      SE               SE
# municipio                    CEDRO DE SAO JOAO       POCO VERDE
# codigo_mun                             2801603          2805505
# capital                                      0                0
# porte                          Pequeno porte 1  Pequeno porte 2
# populacao                                5,912           23,580
# area                                     83.71           439.84
# densidade_dem                             67.3               50
# pib                                   38902.98        185982.88
# pib_pc                                 6654.63          8058.88
# participacao_transf_receita               92.0             92.0
# servidores                               203.0            623.0
# comissionados                             89.0            130.0
# comissionados_por_servidor                 44%              21%
# perc_pop_econ_ativa                       0.77             0.86
# taxa_empreendedorismo                     0.35             0.23
# anos_estudo_empreendedor              6.351568         4.741037
# jornada_trabalho                      35.73114        34.777215
# gasto_pc_saude                          461.83           310.39
# hab_p_medico                             652.0      2113.545455
# exp_vida                                 68.83            70.08
# gasto_pc_educacao                       613.36           645.33
# exp_anos_estudo                           9.08             8.98
# nota_ciencias                       461.052381       463.451337
# nota_humanas                        509.559524       506.520321
# nota_linguagem                      487.254762        496.67043
# nota_mat                            442.495238       453.449462
# nota_redacao                        578.571429       529.677419
# idhm                                      0.43              NaN
# ranking_igm                                NaN              NaN
# indice_governanca                          NaN              NaN
#
#                                                  5248             5249
# regiao                                       NORDESTE         NORDESTE
# estado                                             SE               SE
# municipio                    NOSSA SENHORA DE LOURDES            ITABI
# codigo_mun                                    2804706          2803104
# capital                                             0                0
# porte                                 Pequeno porte 1  Pequeno porte 1
# populacao                                       6,512            5,002
# area                                            81.06           184.42
# densidade_dem                                      77               27
# pib                                          48201.34         38696.88
# pib_pc                                        7466.13          7665.78
# participacao_transf_receita                       NaN              NaN
# servidores                                      236.0            203.0
# comissionados                                    22.0             14.0
# comissionados_por_servidor                         9%               7%
# perc_pop_econ_ativa                              0.79             0.78
# taxa_empreendedorismo                            0.32             0.26
# anos_estudo_empreendedor                     5.141976          4.69656
# jornada_trabalho                            39.708468        38.371606
# gasto_pc_saude                                    NaN              NaN
# hab_p_medico                                  1618.75           2516.0
# exp_vida                                        68.13            69.86
# gasto_pc_educacao                                 NaN              NaN
# exp_anos_estudo                                   9.3             9.91
# nota_ciencias                              445.827184       468.687805
# nota_humanas                               500.052427       494.790244
# nota_linguagem                             485.945098       500.912195
# nota_mat                                   441.245098       469.095122
# nota_redacao                               475.882353       488.780488
# idhm                                             0.37              NaN
# ranking_igm                                       NaN              NaN
# indice_governanca                                 NaN              NaN
#
# [32 rows x 1794 columns]

# %% [markdown]
# ## Explorando Dados do Nordeste

# %% [markdown]
# Para facilitar nossa vida, vamos criar uma variável já filtrada chamada `nordeste`:

# %%
nordeste = igm[filtro]

# %% [markdown]
# Agora temos um `DataFrame` apenas com cidades do Nordeste.

# %%
nordeste.sample(5).T
# Out:
#                                         2778             2862  \
# regiao                              NORDESTE         NORDESTE
# estado                                    PE               PI
# municipio                       BOM CONSELHO    ISAIAS COELHO
# codigo_mun                           2602100          2204907
# capital                                    0                0
# porte                        Pequeno porte 2  Pequeno porte 1
# populacao                             47,991            8,424
# area                                  792.04           776.05
# densidade_dem                           57.4             10.6
# pib                                338802.56         37849.99
# pib_pc                               7166.94          4523.18
# participacao_transf_receita             79.0             93.0
# servidores                             897.0            207.0
# comissionados                           43.0             25.0
# comissionados_por_servidor                5%              12%
# perc_pop_econ_ativa                     0.85             0.62
# taxa_empreendedorismo                   0.25              0.2
# anos_estudo_empreendedor            5.519534         3.840579
# jornada_trabalho                   40.023175        34.022947
# gasto_pc_saude                        256.01           397.77
# hab_p_medico                          1440.0          2097.25
# exp_vida                               67.22             71.0
# gasto_pc_educacao                     702.35            758.5
# exp_anos_estudo                         8.47             8.49
# nota_ciencias                     455.835556          424.808
# nota_humanas                      506.147937          463.088
# nota_linguagem                    501.414516          470.332
# nota_mat                          450.339032          424.384
# nota_redacao                      519.483871            479.2
# idhm                                   0.286            0.332
# ranking_igm                            2779º            2863º
# indice_governanca                      0.408            0.401
#
#                                         4898                   3184  \
# regiao                              NORDESTE               NORDESTE
# estado                                    PB                     PI
# municipio                      CAJAZEIRINHAS  MONTE ALEGRE DO PIAUI
# codigo_mun                           2503753                2206605
# capital                                    0                      0
# porte                        Pequeno porte 1        Pequeno porte 1
# populacao                              3,181                 10,446
# area                                  287.89               2,417.93
# densidade_dem                           10.5                    4.3
# pib                                 24066.03               78273.22
# pib_pc                               7686.37                7498.87
# participacao_transf_receita             96.0                   92.0
# servidores                             182.0                  433.0
# comissionados                           31.0                   23.0
# comissionados_por_servidor               17%                     5%
# perc_pop_econ_ativa                      0.5                   0.75
# taxa_empreendedorismo                   0.22                   0.11
# anos_estudo_empreendedor            3.928777               5.707025
# jornada_trabalho                   32.289417              29.619701
# gasto_pc_saude                        839.52                  408.7
# hab_p_medico                     1049.333333            1740.166667
# exp_vida                               71.35                   71.1
# gasto_pc_educacao                    1204.72                1085.13
# exp_anos_estudo                         8.32                   8.69
# nota_ciencias                     450.327273             431.082609
# nota_humanas                      512.327273             463.533333
# nota_linguagem                    497.766667             459.346377
# nota_mat                          440.357143             425.291304
# nota_redacao                      544.761905             448.115942
# idhm                                   0.255                  0.322
# ranking_igm                              NaN                  3185º
# indice_governanca                        NaN                  0.358
#
#                                          3033
# regiao                               NORDESTE
# estado                                     CE
# municipio                    SAO LUIS DO CURU
# codigo_mun                            2312601
# capital                                     0
# porte                         Pequeno porte 1
# populacao                              12,805
# area                                   122.42
# densidade_dem                           100.7
# pib                                  74996.33
# pib_pc                                5922.48
# participacao_transf_receita              95.0
# servidores                              314.0
# comissionados                            61.0
# comissionados_por_servidor                19%
# perc_pop_econ_ativa                      0.78
# taxa_empreendedorismo                    0.24
# anos_estudo_empreendedor              6.19858
# jornada_trabalho                     42.96629
# gasto_pc_saude                         495.83
# hab_p_medico                      1059.416667
# exp_vida                                68.13
# gasto_pc_educacao                      667.14
# exp_anos_estudo                          9.55
# nota_ciencias                         452.178
# nota_humanas                          489.315
# nota_linguagem                        490.835
# nota_mat                              430.645
# nota_redacao                            477.2
# idhm                                    0.422
# ranking_igm                             3034º
# indice_governanca                       0.383

# %% [markdown]
# Se utilizarmos uma seleção de coluna `indice_governanca` e o `.describe()`, iremos ver o detalhamento dos dados dessa coluna de acordo com o método `.describe()`

# %%
nordeste['perc_pop_econ_ativa'].describe()
# Out:
# count    1794.000000
# mean        0.791488
# std         0.122635
# min         0.290000
# 25%         0.710000
# 50%         0.790000
# 75%         0.870000
# max         1.300000
# Name: perc_pop_econ_ativa, dtype: float64

# %% [markdown]
# Podemos plotar essa distribuição para o Nordeste:

# %%
nordeste['perc_pop_econ_ativa'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# ##  `Exercícios: Filtros`

# %% [markdown]
# 1. Crie um filtro chamado `meu_filtro` para selecionar apenas as linhas onde os valores da coluna `pib_pc` sejam maiores do que 50000
# 2. Crie um novo `DataFrame` chamado `igm_filtrado_pib_pc` aplicando o `meu_filtro` no `igm`
# 3. Utilize o método `.describe()` na coluna `pib_pc` do `igm_filtrado_pib_pc`
# 4. Plote um histograma da coluna `pib_pc` do `igm_filtrado_pib_pc`

# %% [markdown]
# ## Fazendo Filtros com Valores Negativos

# %% [markdown]
# Para pegarmos o valor negativo de uma sequência de `True` ou `False`, podemos usar o `~`

# %%
filtro_nordeste = ~nordeste['perc_pop_econ_ativa'].isnull()

# %% [markdown]
# ## Ordenando um DataFrame que possui uma coluna com NaNs

# %% [markdown]
# Para ordernamos um dataframe por uma coluna basta usarmos o comando `.sort_values()` com o parâmetro `by=nome_da_coluna`. O parâmetro `ascending=False` serve para pegarmos os itens em ordem decrescente.

# %%
nordeste[filtro_nordeste].sort_values(by='perc_pop_econ_ativa', ascending=False)[0:5].T
# Out:
#                                             5005               4060  \
# regiao                                  NORDESTE           NORDESTE
# estado                                        PE                 PI
# municipio                    FERNANDO DE NORONHA  SAO JOSE DO PIAUI
# codigo_mun                               2605459            2210201
# capital                                        0                  0
# porte                            Pequeno porte 1    Pequeno porte 1
# populacao                                  2,974              6,606
# area                                       17.02             364.95
# densidade_dem                              154.6               18.1
# pib                                     75673.98            35426.0
# pib_pc                                  26673.95            5350.55
# participacao_transf_receita                  NaN               94.0
# servidores                                   NaN              272.0
# comissionados                               32.0                7.0
# comissionados_por_servidor               #DIV/0!                 3%
# perc_pop_econ_ativa                          1.3               1.18
# taxa_empreendedorismo                       0.28                0.2
# anos_estudo_empreendedor                9.028445           3.696418
# jornada_trabalho                       47.352657          36.890425
# gasto_pc_saude                               NaN             334.82
# hab_p_medico                                 NaN            1653.75
# exp_vida                                   75.36              67.02
# gasto_pc_educacao                            NaN             565.31
# exp_anos_estudo                            10.76               9.12
# nota_ciencias                              483.8              449.5
# nota_humanas                          548.046154             489.55
# nota_linguagem                        528.269231         472.303846
# nota_mat                              467.530769         430.717308
# nota_redacao                               540.0         496.538462
# idhm                                       0.823                NaN
# ranking_igm                                  NaN                NaN
# indice_governanca                            NaN                NaN
#
#                                                  2423             4901  \
# regiao                                       NORDESTE         NORDESTE
# estado                                             PE               PB
# municipio                    SANTA CRUZ DO CAPIBARIBE      SANTO ANDRE
# codigo_mun                                    2612505          2513851
# capital                                             0                0
# porte                                    Grande porte  Pequeno porte 1
# populacao                                     103,660            2,529
# area                                           335.31           197.71
# densidade_dem                                   261.2             11.7
# pib                                        1115053.53         19632.22
# pib_pc                                       11506.31          7653.89
# participacao_transf_receita                      80.0             96.0
# servidores                                     1279.0             99.0
# comissionados                                   250.0             75.0
# comissionados_por_servidor                        20%              76%
# perc_pop_econ_ativa                              1.16             1.15
# taxa_empreendedorismo                            0.41             0.26
# anos_estudo_empreendedor                     5.871794         4.256194
# jornada_trabalho                             41.27791        41.211917
# gasto_pc_saude                                 286.66           934.73
# hab_p_medico                              4725.333333            851.0
# exp_vida                                        73.35            72.79
# gasto_pc_educacao                              380.68          1110.59
# exp_anos_estudo                                  8.34             9.35
# nota_ciencias                              472.550424           443.82
# nota_humanas                               530.972848          476.036
# nota_linguagem                              512.22113          464.472
# nota_mat                                   484.590418          447.296
# nota_redacao                                549.64742            471.2
# idhm                                            0.489              NaN
# ranking_igm                                     2424º              NaN
# indice_governanca                               0.442              NaN
#
#                                         4989
# regiao                              NORDESTE
# estado                                    PE
# municipio                             MANARI
# codigo_mun                           2609154
# capital                                    0
# porte                        Pequeno porte 2
# populacao                             20,681
# area                                  344.73
# densidade_dem                           47.6
# pib                                  87870.7
# pib_pc                               4440.61
# participacao_transf_receita             90.0
# servidores                             614.0
# comissionados                            7.0
# comissionados_por_servidor                1%
# perc_pop_econ_ativa                     1.15
# taxa_empreendedorismo                   0.29
# anos_estudo_empreendedor            3.194962
# jornada_trabalho                   36.649292
# gasto_pc_saude                        259.56
# hab_p_medico                          3982.0
# exp_vida                               65.89
# gasto_pc_educacao                     810.53
# exp_anos_estudo                          7.8
# nota_ciencias                     433.614286
# nota_humanas                      469.185714
# nota_linguagem                    456.573529
# nota_mat                          428.820588
# nota_redacao                      437.058824
# idhm                                   0.105
# ranking_igm                              NaN
# indice_governanca                        NaN

# %% [markdown]
# ## Usando vários filtros ao mesmo tempo

# %% [markdown]
# Vamos criar um novo filtro para o `DataFrame` inteiro e não só para o Nordeste.

# %%
filtro_2 = ~igm['perc_pop_econ_ativa'].isnull()

# %% [markdown]
# Outra forma de escrever isso é utilizando dois filtros ao mesmo tempo, para isso temos que usar o operador lógico `&` que representa `E`, também temos a oportunidade usar o operador lógico `|`, que significa `OU`:

# %%
igm[filtro & filtro_2].sort_values(by='perc_pop_econ_ativa', ascending=False)[0:5].T
# Out:
#                                             5005               4060  \
# regiao                                  NORDESTE           NORDESTE
# estado                                        PE                 PI
# municipio                    FERNANDO DE NORONHA  SAO JOSE DO PIAUI
# codigo_mun                               2605459            2210201
# capital                                        0                  0
# porte                            Pequeno porte 1    Pequeno porte 1
# populacao                                  2,974              6,606
# area                                       17.02             364.95
# densidade_dem                              154.6               18.1
# pib                                     75673.98            35426.0
# pib_pc                                  26673.95            5350.55
# participacao_transf_receita                  NaN               94.0
# servidores                                   NaN              272.0
# comissionados                               32.0                7.0
# comissionados_por_servidor               #DIV/0!                 3%
# perc_pop_econ_ativa                          1.3               1.18
# taxa_empreendedorismo                       0.28                0.2
# anos_estudo_empreendedor                9.028445           3.696418
# jornada_trabalho                       47.352657          36.890425
# gasto_pc_saude                               NaN             334.82
# hab_p_medico                                 NaN            1653.75
# exp_vida                                   75.36              67.02
# gasto_pc_educacao                            NaN             565.31
# exp_anos_estudo                            10.76               9.12
# nota_ciencias                              483.8              449.5
# nota_humanas                          548.046154             489.55
# nota_linguagem                        528.269231         472.303846
# nota_mat                              467.530769         430.717308
# nota_redacao                               540.0         496.538462
# idhm                                       0.823                NaN
# ranking_igm                                  NaN                NaN
# indice_governanca                            NaN                NaN
#
#                                                  2423             4901  \
# regiao                                       NORDESTE         NORDESTE
# estado                                             PE               PB
# municipio                    SANTA CRUZ DO CAPIBARIBE      SANTO ANDRE
# codigo_mun                                    2612505          2513851
# capital                                             0                0
# porte                                    Grande porte  Pequeno porte 1
# populacao                                     103,660            2,529
# area                                           335.31           197.71
# densidade_dem                                   261.2             11.7
# pib                                        1115053.53         19632.22
# pib_pc                                       11506.31          7653.89
# participacao_transf_receita                      80.0             96.0
# servidores                                     1279.0             99.0
# comissionados                                   250.0             75.0
# comissionados_por_servidor                        20%              76%
# perc_pop_econ_ativa                              1.16             1.15
# taxa_empreendedorismo                            0.41             0.26
# anos_estudo_empreendedor                     5.871794         4.256194
# jornada_trabalho                             41.27791        41.211917
# gasto_pc_saude                                 286.66           934.73
# hab_p_medico                              4725.333333            851.0
# exp_vida                                        73.35            72.79
# gasto_pc_educacao                              380.68          1110.59
# exp_anos_estudo                                  8.34             9.35
# nota_ciencias                              472.550424           443.82
# nota_humanas                               530.972848          476.036
# nota_linguagem                              512.22113          464.472
# nota_mat                                   484.590418          447.296
# nota_redacao                                549.64742            471.2
# idhm                                            0.489              NaN
# ranking_igm                                     2424º              NaN
# indice_governanca                               0.442              NaN
#
#                                         4989
# regiao                              NORDESTE
# estado                                    PE
# municipio                             MANARI
# codigo_mun                           2609154
# capital                                    0
# porte                        Pequeno porte 2
# populacao                             20,681
# area                                  344.73
# densidade_dem                           47.6
# pib                                  87870.7
# pib_pc                               4440.61
# participacao_transf_receita             90.0
# servidores                             614.0
# comissionados                            7.0
# comissionados_por_servidor                1%
# perc_pop_econ_ativa                     1.15
# taxa_empreendedorismo                   0.29
# anos_estudo_empreendedor            3.194962
# jornada_trabalho                   36.649292
# gasto_pc_saude                        259.56
# hab_p_medico                          3982.0
# exp_vida                               65.89
# gasto_pc_educacao                     810.53
# exp_anos_estudo                          7.8
# nota_ciencias                     433.614286
# nota_humanas                      469.185714
# nota_linguagem                    456.573529
# nota_mat                          428.820588
# nota_redacao                      437.058824
# idhm                                   0.105
# ranking_igm                              NaN
# indice_governanca                        NaN

# %% [markdown]
# ## Avaliando o tamanho dos DataFrames e Series

# %% [markdown]
# Para sabermos o tamanho de um `DataFrame` usamos o comando `.shape`

# %%
igm.shape
# Out:
# (5570, 32)

# %% [markdown]
# O `DataFrame` feito a partir do `filtro` é menor como de se esperar:

# %%
nordeste.shape
# Out:
# (1794, 32)

# %% [markdown]
# Podemos fazer o `.shape` de uma `Series`

# %%
igm['municipio'].shape
# Out:
# (5570,)

# %% [markdown]
# Note pelo comando a seguir como o shape é diferente entre a seleção com:
# 1. `[]` - `Series` - 1 dimensão
# 2. `[[]]` - `DataFrame` - 2 dimensões

# %%
igm[['municipio']].shape
# Out:
# (5570, 1)

# %% [markdown]
# Podemos usar o `.shape` em uma `Series` também, que nos retornará apenas 1 dimensão.

# %%
filtro.shape
# Out:
# (5570,)

# %% [markdown]
# Note que o `filtro_nordeste` tem o mesmo número de linhas do `DataFrame` que o originou

# %%
filtro_nordeste.shape
# Out:
# (1794,)

# %% [markdown]
# Note que o segundo filtro que utilizamos tem o mesmo tamanho do primeiro filtro e do `DataFrame` original

# %%
filtro_2.shape
# Out:
# (5570,)

# %% [markdown]
# De preferência devemos usar um filtro do mesmo tamanho que um `DataFrame` para fazer as seleções. Mas se jogarmos um filtro maior em um `DataFrame` que é um subconjunto do `DataFrame` original, irá funcionar porque ele irá se guiar pelo `index`, mas irá retornar um aviso.
#
# Se algum aviso desse tipo acontecer, você já tem uma boa ideia do que pode ter acontecido.

# %%
nordeste[filtro_2]
# Out:
# /tmp/ipykernel_60906/1071761029.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#         regiao estado                 municipio  codigo_mun  capital  \
# 67    NORDESTE     PE                   IPOJUCA     2607208        0
# 77    NORDESTE     CE                 FORTALEZA     2304400        1
# 236   NORDESTE     BA          MATA DE SAO JOAO     2921005        0
# 241   NORDESTE     PB               JOAO PESSOA     2507507        1
# 261   NORDESTE     CE                   EUSEBIO     2304285        0
# ...        ...    ...                       ...         ...      ...
# 5245  NORDESTE     SE              SAO DOMINGOS     2806800        0
# 5246  NORDESTE     SE         CEDRO DE SAO JOAO     2801603        0
# 5247  NORDESTE     SE                POCO VERDE     2805505        0
# 5248  NORDESTE     SE  NOSSA SENHORA DE LOURDES     2804706        0
# 5249  NORDESTE     SE                     ITABI     2803104        0
#
#                 porte  populacao    area densidade_dem          pib  ...  \
# 67        Médio porte     92,965  527.11           153   8411558.28  ...
# 77       Grande porte  2,609,716  314.93      7,786.40  49745920.35  ...
# 236   Pequeno porte 2     46,392   633.2          63.5    981822.66  ...
# 241      Grande porte    801,718  211.48      3,421.30  14841805.03  ...
# 261       Médio porte     51,913   79.01         582.7   2077064.42  ...
# ...               ...        ...     ...           ...          ...  ...
# 5245  Pequeno porte 1     11,053     102         100.2     93161.64  ...
# 5246  Pequeno porte 1      5,912   83.71          67.3     38902.98  ...
# 5247  Pequeno porte 2     23,580  439.84            50    185982.88  ...
# 5248  Pequeno porte 1      6,512   81.06            77     48201.34  ...
# 5249  Pequeno porte 1      5,002  184.42            27     38696.88  ...
#
#       gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# 67              1779.61             8.65     463.458278    505.182119
# 77               382.80            10.04     492.416843    542.762946
# 236             1232.37             8.65     448.619011    508.202281
# 241              428.25             9.87     497.310587    548.607283
# 261             1112.71            10.13     479.490850    521.400000
# ...                 ...              ...            ...           ...
# 5245             686.34             9.06     465.242000    501.113000
# 5246             613.36             9.08     461.052381    509.559524
# 5247             645.33             8.98     463.451337    506.520321
# 5248                NaN             9.30     445.827184    500.052427
# 5249                NaN             9.91     468.687805    494.790244
#
#      nota_linguagem    nota_mat  nota_redacao   idhm  ranking_igm  \
# 67       503.076629  449.237753    480.988764  0.420          68º
# 77       525.144742  500.962286    574.679852  0.742          78º
# 236      493.710305  442.017176    472.366412  0.537         237º
# 241      529.736787  507.429430    594.096408  0.764         242º
# 261      507.040535  480.173051    515.209354  0.616         262º
# ...             ...         ...           ...    ...          ...
# 5245     485.569697  459.546465    517.979798  0.346          NaN
# 5246     487.254762  442.495238    578.571429  0.430          NaN
# 5247     496.670430  453.449462    529.677419    NaN          NaN
# 5248     485.945098  441.245098    475.882353  0.370          NaN
# 5249     500.912195  469.095122    488.780488    NaN          NaN
#
#       indice_governanca
# 67                0.659
# 77                0.656
# 236               0.622
# 241               0.622
# 261               0.619
# ...                 ...
# 5245                NaN
# 5246                NaN
# 5247                NaN
# 5248                NaN
# 5249                NaN
#
# [1794 rows x 32 columns]

# %% [markdown]
# ##  `Exercícios: Mais Filtros e Shape`
#
# 1. Crie um filtro chamado `filtro_com_idhm` que selecione as cidades que não tenham o `idhm` em branco.
# 2. Crie um filtro chamado `filtro_trabalho` que selecione as cidades que o valor de `jornada_trabalho` seja maior do que 50
# 3. Crie um novo `DataFrame` chamado `igm_idhm_e_trabalho` que use os filtros `filtro_com_idhm` e `filtro_trabalho` com o operador `E` - `&`
# 4. Crie um novo `DataFrame` chamado `igm_idhm_ou_trabalho` que use os filtros `filtro_com_idhm` e `filtro_trabalho` com o operador `OU` - `|`
# 5. Pegue o `.shape` dos `DataFrames` dos itens `3` e `4`

# %% [markdown]
# ## Manipulação de Strings

# %% [markdown]
# Agora nós iremos atualizar a densidade demográfica da tabela com um valor mais recente. Para isso temos que transformar as colunas de area e de populacao em números (`float` ou `int`), atualmente elas estão em forma de texto (`str`)

# %% [markdown]
# ## Avaliando os tipos do nosso DataFrame

# %%
igm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   regiao                       5570 non-null   object
#  1   estado                       5570 non-null   object
#  2   municipio                    5570 non-null   object
#  3   codigo_mun                   5570 non-null   int64
#  4   capital                      5570 non-null   int64
#  5   porte                        5570 non-null   object
#  6   populacao                    5570 non-null   object
#  7   area                         5570 non-null   object
#  8   densidade_dem                5566 non-null   object
#  9   pib                          5570 non-null   float64
#  10  pib_pc                       5570 non-null   float64
#  11  participacao_transf_receita  4893 non-null   float64
#  12  servidores                   5233 non-null   float64
#  13  comissionados                5570 non-null   float64
#  14  comissionados_por_servidor   5570 non-null   object
#  15  perc_pop_econ_ativa          5565 non-null   float64
#  16  taxa_empreendedorismo        5570 non-null   float64
#  17  anos_estudo_empreendedor     5570 non-null   float64
#  18  jornada_trabalho             5570 non-null   float64
#  19  gasto_pc_saude               4881 non-null   float64
#  20  hab_p_medico                 4951 non-null   float64
#  21  exp_vida                     5565 non-null   float64
#  22  gasto_pc_educacao            4880 non-null   float64
#  23  exp_anos_estudo              5565 non-null   float64
#  24  nota_ciencias                5558 non-null   float64
#  25  nota_humanas                 5558 non-null   float64
#  26  nota_linguagem               5557 non-null   float64
#  27  nota_mat                     5557 non-null   float64
#  28  nota_redacao                 5557 non-null   float64
#  29  idhm                         4986 non-null   float64
#  30  ranking_igm                  3303 non-null   object
#  31  indice_governanca            3303 non-null   float64
# dtypes: float64(21), int64(2), object(9)
# memory usage: 1.4+ MB

# %% [markdown]
# Como podemos notar, temos algumas colunas que são númeircas mas que estão como `object`, o que normalmente irá significar que são texto. Vamos avaliar o que está acontecendo.

# %% [markdown]
# ## Comparando Densidades

# %% [markdown]
# Uma forma interessante de facilitar a nossa visualização o DataFrame é selecionando apenas algumas colunas que nos interessam, como no caso da densidade demográfica: `municipio`, `populacao`, `area`, `densidade_dem` e `densidade_2`, para isso basta colocarmos `igm[[]]` com os nomes das colunas dentro separados por vírgula (lembrando das aspas para identificar que é um texto).

# %%
igm[['municipio','populacao','area','densidade_dem']].sample(10)
# Out:
#                 municipio populacao      area densidade_dem
# 929          NOVA BASSANO     9,540    211.61          41.8
# 576              SAUDADES     9,594     206.6          43.6
# 1833   PETROLINA DE GOIAS    10,548     531.3          19.4
# 1950              PARECIS     5,802  2,548.68           1.9
# 802             ESMERALDA     3,307    829.77           3.8
# 2958  BURITI DO TOCANTINS    10,988    251.92          38.8
# 903               ITARUMA     6,927  3,433.63           1.8
# 4103             ORIZANIA     7,891     121.8          59.8
# 3371           BOM JARDIM    26,424    384.64          65.9
# 444               MELEIRO     7,056    187.06          37.4

# %% [markdown]
# ##  `Exercícios: Manipulação de Strings`
#
# 1. Transforme a coluna `ranking_igm` para uma coluna numérica
# 2. Crie uma coluna `comissionados_por_servidor_2` a partir das colunas `comissionados` e `servidores`
# 3. Substitua a coluna `comissionados_por_servidor` se for o caso
# 4. Delete a coluna `comissionados_por_servidor_2`

# %%
igm['comissionados_por_servidor'] = igm['comissionados']/igm['servidores']

# %% [markdown]
# ## Revisão

# %% [markdown]
# Fazer revisão do que foi visto.

# %% [markdown]
# ## `Exercícios: Revisão`
#
# 1. Plotar um histograma da coluna `exp_vida`
# 2. Usar o método `.describe` na coluna `exp_vida`
# 3. Usar o método `.describe` na coluna `exp_vida` onde os municípios sejam apenas da região `NORTE`
# 4. Usar o método `.value_counts()` na coluna `estado` filtrando os munícipios que tenham `pib_pc` > 50000
# 5. Plotar um gráfico de barras do resultado gerado pelo item 4

# %% [markdown]
# ## Conteúdos Adicionais

# %% [markdown]
# ### Gráficos Interativos

# %% [markdown]
# Um jeito bem interessante de fazermos histogramas é com gráficos interativos, um boa biblioteca para fazer isso é a `plotly`, para instalarmos ela, basta usarmos o comando `!pip install plotly`

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /home/suzanamota/.local/lib/python3.8/site-packages (6.3.0)
# Requirement already satisfied: packaging in /home/suzanamota/.local/lib/python3.8/site-packages (from plotly) (23.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/suzanamota/.local/lib/python3.8/site-packages (from plotly) (1.42.1)

# %% [markdown]
# Vamos precisar importar duas sub-bibliotecas da `plotly`, importante notar que estamos usando o modo `offline` para facilitar a nossa vida e não necessitarmos de autenticação no site deles.

# %%
import plotly.offline as plotly
import plotly.graph_objs as go

# %% [markdown]
# ## Histograma: Trocando Valores Absolutos por Probabilidades

# %% [markdown]
# Para vermos a probabilidade de dado valor acontecer em vez de quantos valores daquele tipo aconteceram, basta usar o parâmetro `histnorm='probability'`:

# %%
pyplot_data_norm = [go.Histogram(x=igm['exp_vida'], histnorm='probability')]

# %% [markdown]
# Para plotar o gráfico usamos o `plotly.iplot()`

# %%
plotly.iplot(pyplot_data_norm)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="b5ab9448-ac24-4f46-96c8-0808962b44c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b5ab9448-ac24-4f46-96c8-0808962b44c7")) {                    Plotly.newPlot(                        "b5ab9448-ac24-4f46-96c8-0808962b44c7",                        [{"histnorm":"probability","x":{"dtype":"f8","bdata":"pHA9CtfjUkB7FK5H4fpSQNejcD0KN1NAmpmZmZkpU0BmZmZmZlZTQLgehetRCFNArkfhehTOUkApXI\u002fC9ShTQEjhehSup1NA16NwPQqnU0BxPQrXo2BTQFyPwvUoPFNA4XoUrkchUkCF61G4HlVTQFK4HoXrEVNApHA9CtezUkAzMzMzMxNTQLgehetR+FJAFK5H4XoUU0AAAAAAAFBTQOxRuB6Fy1JAH4XrUbgOU0DNzMzMzMxSQPYoXI\u002fC5VJAuB6F61GYUkApXI\u002fC9WhSQAAAAAAAYFNAFK5H4XrEUkDD9Shcj7JSQDMzMzMz81JAexSuR+EaU0DhehSuR+FSQClcj8L1SFJAZmZmZmYWU0C4HoXrUUhTQM3MzMzM\u002fFJA7FG4HoVrUkDsUbgehVtTQEjhehSuF1NAKVyPwvWIU0CPwvUoXO9SQClcj8L1qFNA7FG4HoV7U0BxPQrXo\u002fBSQNejcD0KB1NAuB6F61GIU0C4HoXrUchSQI\u002fC9ShcL1NAexSuR+E6U0ApXI\u002fC9VhTQLgehetRqFJAw\u002fUoXI\u002fSUkAfhetRuG5TQLgehetR2FJACtejcD1qU0CkcD0K14NTQBSuR+F65FJACtejcD3aUkApXI\u002fC9WhSQEjhehSu91JArkfhehROU0AzMzMzMxNTQJqZmZmZ6VJA16NwPQoHU0AAAAAAAGBSQClcj8L1qFNAAAAAAADwUkBcj8L1KNxRQD0K16NwvVJAKVyPwvWIU0DhehSuR4FTQJqZmZmZGVNA7FG4HoW7UkDXo3A9ChdTQI\u002fC9Shc\\u002fC9SgcU0ApXI\u002fC9ThSQPYoXI\u002fChVNAhetRuB5lU0DXo3A9CodTQAAAAAAAMFNA4XoUrkfhUkAfhetRuI5SQK5H4XoU3lJA16NwPQoHU0A9CtejcO1SQLgehetR+FJAj8L1KFx\u002fU0Bcj8L1KJxTQKRwPQrXc1NAexSuR+GaUkCamZmZmUlTQNejcD0K51JAuB6F61EIU0BI4XoUrudSQOF6FK5HQVNAzczMzMzcUkB7FK5H4cpSQKRwPQrXE1NAuB6F61HIUUDXo3A9CgdTQHsUrkfhilNAH4XrUbgOU0CamZmZmclSQBSuR+F6dFNA9ihcj8IlU0CPwvUoXO9SQAAAAAAAcFJA4XoUrkcBU0DNzMzMzIxSQK5H4XoUzlJAXI\\u002fC9ehSQAAAAAAAMFNAFK5H4XrkUkDsUbgehetSQEjhehSuB1NA4XoUrkchU0DhehSuR2FTQKRwPQrXE1NA9ihcj8JlUkA9CtejcK1SQClcj8L1yFJAw\u002fUoXI\\u002fC9SjcUkDXo3A9CldTQD0K16NwTVNAKVyPwvUoUkBI4XoUrudSQKRwPQrXQ1JArkfhehROUkBxPQrXoxBTQHsUrkfhClNAhetRuB4lU0DNzMzMzIxSQK5H4XoULlNAKVyPwvXIUkCF61G4HvVSQLgehetR2FJAw\u002fUoXI+yUkDXo3A9CkdTQArXo3A9KlJApHA9CteDU0BxPQrXo\u002fBSQDMzMzMz81JAexSuR+FaU0AAAAAAACBTQK5H4XoUblNAUrgeheuBUkDXo3A9CudSQJqZmZmZmVJAzczMzMzMUkCF61G4HnVSQPYoXI\u002fChVJAH4XrUbj+UkCamZmZmZlSQB+F61G4flNAPQrXo3CdUkApXI\u002fC9bhSQMP1KFyPYlNAPQrXo3B9UkCkcD0K14NTQArXo3A92lJAw\u002fUoXI9CU0DNzMzMzHxSQJqZmZmZ6VJACtejcD3aUkApXI\\u002fC9WhTQKRwPQrX41JArkfhehT+UkD2KFyPwiVTQGZmZmZm5lJAAAAAAABwUkCF61G4HtVSQI\u002fC9ShcP1NAw\u002fUoXI+yUkDhehSuR4FTQDMzMzMzY1JAexSuR+GaUkCPwvUoXN9SQEjhehSuV1NAXI\u002fC9SjMUkBSuB6F61FTQK5H4XoUHlNAKVyPwvXoUkAAAAAAADBTQNejcD0Kp ...

# %% [markdown]
# ## Plotando Múltiplos Gráficos

# %% [markdown]
# Uma funcionalidade bem legal das bibliotecas gráficas do Python é que podemos plotar um gráfico em cima do outro.
#
# Para isso vamos começar plotando um gráfico simples.

# %%
sns.distplot(igm[igm['regiao'] == 'NORDESTE']['indice_governanca'].dropna(), label='NORDESTE')
# Out:
# /tmp/ipykernel_60906/2304164284.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='indice_governanca', ylabel='Density'>

# %% [markdown]
# Vamos plotar outro gráfico simples.

# %%
sns.distplot(igm[igm['regiao'] == 'SUDESTE']['indice_governanca'].dropna(), label='SUDESTE')
# Out:
# /tmp/ipykernel_60906/4234394133.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='indice_governanca', ylabel='Density'>

# %% [markdown]
# ## Índice de Governança por Região

# %% [markdown]
# Para plotar vários gráficos ao mesmo tempo com legenda, vamos precisar importar uma parte do `matplotlib`:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Vamos plotar os dois gráficos que plotamos anteriormente, só que agora ao mesmo tempo, note como eles ficaram diferentes:

# %%
sns.distplot(igm[igm['regiao'] == 'NORDESTE']['indice_governanca'].dropna(), label='NORDESTE')
sns.distplot(igm[igm['regiao'] == 'SUDESTE']['indice_governanca'].dropna(), label='SUDESTE')
plt.legend()
# Out:
# /tmp/ipykernel_60906/2189436034.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_60906/2189436034.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Vamos plotar 3 gráficos ao mesmo tempo:

# %%
sns.distplot(igm[igm['regiao'] == 'NORDESTE']['indice_governanca'].dropna(), label='NORDESTE')
sns.distplot(igm[igm['regiao'] == 'SUDESTE']['indice_governanca'].dropna(), label='SUDESTE')
sns.distplot(igm[igm['regiao'] == 'CENTRO-OESTE']['indice_governanca'].dropna(), label='CENTRO-OESTE')
plt.legend()
# Out:
# /tmp/ipykernel_60906/524579915.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_60906/524579915.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_60906/524579915.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# E finalmente vamos plotar 5 gráficos ao mesmo tempo:

# %%
sns.distplot(igm[igm['regiao'] == 'NORDESTE']['indice_governanca'].dropna(), label='NORDESTE')
sns.distplot(igm[igm['regiao'] == 'SUDESTE']['indice_governanca'].dropna(), label='SUDESTE')
sns.distplot(igm[igm['regiao'] == 'NORTE']['indice_governanca'].dropna(), label='NORTE')
sns.distplot(igm[igm['regiao'] == 'SUL']['indice_governanca'].dropna(), label='SUL')
sns.distplot(igm[igm['regiao'] == 'CENTRO-OESTE']['indice_governanca'].dropna(), label='CENTRO-OESTE')
plt.legend()
# Out:
# /tmp/ipykernel_60906/3355818391.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_60906/3355818391.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_60906/3355818391.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_60906/3355818391.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_60906/3355818391.py:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# ##  `Exercícios: Plotando Múltiplos Gráficos`
#
# 1. Plote os gráficos de `exp_vida`de acordo com o `porte`
# 2. Adicione legendas ao gráfico

# %% [markdown]
# # Visualizando Categorias

# %% [markdown]
# É bastante comum na ciência de dados se classificar váriaveis em:
#     1. Categóricas - Poucas opções de variabilidade
#     2. Contínuas - Muitas opções de variabilidade
#
# Uma forma muito boa de entender as suas variáveis categóricas é utilizando o comando `nunique()`, ele irá te mostrar quantos valores únicos existem para cada coluna.

# %%
igm.nunique()
# Out:
# regiao                            5
# estado                           27
# municipio                      5290
# codigo_mun                     5570
# capital                           2
# porte                             4
# populacao                      5114
# area                           5451
# densidade_dem                  1549
# pib                            5569
# pib_pc                         5560
# participacao_transf_receita      73
# servidores                     1542
# comissionados                   497
# comissionados_por_servidor     4488
# perc_pop_econ_ativa             119
# taxa_empreendedorismo            73
# anos_estudo_empreendedor       5566
# jornada_trabalho               5566
# gasto_pc_saude                 4737
# hab_p_medico                   4757
# exp_vida                       1135
# gasto_pc_educacao              4741
# exp_anos_estudo                 580
# nota_ciencias                  5545
# nota_humanas                   5546
# nota_linguagem                 5544
# nota_mat                       5547
# nota_redacao                   4447
# idhm                            342
# ranking_igm                    3303
# indice_governanca               390
# dtype: int64

# %% [markdown]
# Basicamente as três variáveis categóricas com poucas opções que temos são `região`, `capital` e `porte`.
#
# Além disso temos `estado`, mas que não iria ficar tão bom para plotar gráficos. `participacao_transf_receita` e `taxa_empreendedorismo` também podem ser trabalhadas como variáveis categóricas já que apesar de serem uma porcentagem, os decimals se perderam e acabamos tendo poucas opções de variabilidade.

# %% [markdown]
# ## Boxplot

# %% [markdown]
# Vamos avaliar como cada `regiao` se sai em relação ao `indice_governanca`

# %%
sns.boxplot(x="regiao", y="indice_governanca", data=igm)
# Out:
# <Axes: xlabel='regiao', ylabel='indice_governanca'>

# %% [markdown]
# ## Violin plot

# %% [markdown]
# Uma forma mais elaborada de fazer isso é com o violin plot, que além de fazer os quartis, plota em seu lado as distribuições dos valores.

# %%
sns.violinplot(x="regiao", y="indice_governanca", data=igm)
# Out:
# <Axes: xlabel='regiao', ylabel='indice_governanca'>

# %% [markdown]
# Podemos adicionar mais um agrupamento no gráfico com o comando `hue`:

# %%
sns.violinplot(x="regiao", y="indice_governanca", data=igm, hue='capital')
# Out:
# <Axes: xlabel='regiao', ylabel='indice_governanca'>

# %% [markdown]
# E inclusive plotar 20 pequenos gráficos de violino ao mesmo tempo:

# %%
sns.violinplot(x="regiao", y="indice_governanca", data=igm, hue='porte')
# Out:
# <Axes: xlabel='regiao', ylabel='indice_governanca'>

# %% [markdown]
# Uma forma para facilitar a visualização dos gráficos acima é usando o `factorplot`, que funciona tanto com linhas quant com colunas.

# %% [markdown]
# ## Análisando Frequência:
#
# Para contarmos quantas ocorrências temos por cada categoria podemos usar o `.countplot()`

# %%
sns.countplot(x='regiao', data=igm)
# Out:
# <Axes: xlabel='regiao', ylabel='count'>

# %% [markdown]
# Podemos usar também o `hue` para fazermos uma contagem levando em consideração outra dimensão.

# %%
sns.countplot(x='regiao', hue='porte', data=igm)
# Out:
# <Axes: xlabel='regiao', ylabel='count'>

# %% [markdown]
# ##  `Exercícios: Visualizando Categorias`
#
# 1. Fazer um `boxplot` de `porte` no eixo `x` e `exp_vida` no eixo `y`
# 2. Fazer um `violinplot` de `porte` no eixo `x` e `exp_vida` no eixo `y` com `hue=regiao`
# 3. Criar um `factorplot`  do tipo `box` com `porte` no eixo `x` e `exp_vida` no eixo `y` e `col='regiao'`
# 4. Pegar o `factorplot` do item 1 e substituir `col='regiao'` por `row='regiao'`
# 5. Fazer um `factorplot` usando `kind='count'`, `hue='porte'` e `x='regiao'`

# %% [markdown]
# ## Gráfico de Pizza:
# Use com moderação, com poucas variáveis e sempre com os valores inscritos nos pedaços de pizza

# %%
igm['regiao'].value_counts().index
# Out:
# Index(['NORDESTE', 'SUDESTE', 'SUL', 'CENTRO-OESTE', 'NORTE'], dtype='object', name='regiao')

# %% [markdown]
# Em `labels` colocamos os nomes das regiões, e em `values` colocamos os valores:

# %%
pie_chart = go.Pie(labels=igm['regiao'].value_counts().index, values=igm['regiao'].value_counts())
plotly.iplot([pie_chart])
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="4f9424f1-b186-4c98-9677-466d3974b8f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4f9424f1-b186-4c98-9677-466d3974b8f3")) {                    Plotly.newPlot(                        "4f9424f1-b186-4c98-9677-466d3974b8f3",                        [{"labels":["NORDESTE","SUDESTE","SUL","CENTRO-OESTE","NORTE"],"values":{"dtype":"i2","bdata":"AgeEBqcE0wHCAQ=="},"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"marker":{"col ...
#
# var gd = document.getElementById('4f9424f1-b186-4c98-9677-466d3974b8f3');
# var

# %% [markdown]
# ## Criando novas variáveis categóricas a partir de valores em branco

# %% [markdown]
# Um tipo de variável categórica bastante interessante de avaliar são os valores em branco:

# %%
igm.isnull().sum()
# Out:
# regiao                            0
# estado                            0
# municipio                         0
# codigo_mun                        0
# capital                           0
# porte                             0
# populacao                         0
# area                              0
# densidade_dem                     4
# pib                               0
# pib_pc                            0
# participacao_transf_receita     677
# servidores                      337
# comissionados                     0
# comissionados_por_servidor      337
# perc_pop_econ_ativa               5
# taxa_empreendedorismo             0
# anos_estudo_empreendedor          0
# jornada_trabalho                  0
# gasto_pc_saude                  689
# hab_p_medico                    619
# exp_vida                          5
# gasto_pc_educacao               690
# exp_anos_estudo                   5
# nota_ciencias                    12
# nota_humanas                     12
# nota_linguagem                   13
# nota_mat                         13
# nota_redacao                     13
# idhm                            584
# ranking_igm                    2267
# indice_governanca              2267
# dtype: int64

# %% [markdown]
# Para criarmos ela basta rodarmos método `.isnull()` e assinalar os valores ao uma nova coluna `sem_igm`:

# %%
igm['sem_igm'] = igm['indice_governanca'].isnull()

# %% [markdown]
# Agora plotamos o gráfico e podemos observar, que a falta de um IGM, indica uma menor expectativa de vida na maioria das regiões.

# %%
sns.violinplot(x="regiao", y="gasto_pc_educacao", data=igm, hue='sem_igm')
# Out:
# <Axes: xlabel='regiao', ylabel='gasto_pc_educacao'>

# %%
igm['sem_gasto_pc_saude'] = igm['gasto_pc_saude'].isnull()

# %%
sns.violinplot(x="regiao", y="nota_mat", data=igm, hue='sem_gasto_pc_saude')
# Out:
# <Axes: xlabel='regiao', ylabel='nota_mat'>

# %% [markdown]
# ## Groupby

# %% [markdown]
# Os gráficos acima estão pegando uma variável contínua e claculando a média dela para uma dada região, para replicarmos o gráfico acima em números poderíamos utilizar o seguinte comando:

# %%
igm.groupby('regiao')['pib_pc'].mean()
# Out:
# regiao
# CENTRO-OESTE    23911.187623
# NORDESTE         8159.934108
# NORTE           12249.159778
# SUDESTE         21024.014323
# SUL             25516.579941
# Name: pib_pc, dtype: float64

# %% [markdown]
# Para converter para `log` podemos usar o `numpy` que é uma biblioteca bastante importante para manipulação de dados, e é a base do `pandas`.

# %%
import numpy as np

# %% [markdown]
# Vamos criar uma coluna nova `log_pop` com os valores logarítimicos da `populacao` por meio da função `.log()` do `numpy`:

# %%
igm['log_pop'] = np.log(igm['populacao'])

# %% [markdown]
# Vamos plotar o gráfico de novo substituindo `populacao` por `log_pop`

# %%
sns.pairplot(x_vars=['log_pop'], y_vars=['indice_governanca'], data=igm, hue="regiao", kind='reg', size=5)

# %% [markdown]
# ##  `Exercícios: Plots usando Escala logarítimica`
#
# 1. Plote um `pairplot` de `anos_estudo_empreendedor` por `pib_pc`
# 2. Crie uma nova variável chamada `log_pib_pc` com o log de `pib_pc`
# 3. Plote um `pairplot` de `anos_estudo_empreendedor` por `log_pib_pc`

# %% [markdown]
# ## Projeto:
#
# Pegue algum dataset de sua escolha ou vá em http://dados.gov.br/ e escolha algum conjunto de dados que te interesse.
#
# De posse desses conjunto de dados faça os seguintes passos:
# 1. Importe o seu conjunto de dados como um `DataFrame`
# 2. Faça a conversão das colunas que estiverem com formato inadequado (números que estão em formato de `str`)
# 3. Faça 8 gráficos a partir dos seus dados
# 4. Faça um resumo dos principais pontos encontrados nos gráficos avaliados

# %% [markdown]
# ## Bônus: Mostrando Valores como um Percentual

# %% [markdown]
# A opção mais recomendada é usar o `.style.format()`, que irá mexer apenas na exibição dos dados e não irá alterar a estrutura dos dados em si.
#
# Para usarmos o `.style.format()`, primeiro precisamos de criar um `dict` com o nome da coluna e o tipo de formatação que desejamos:

# %%
format_dict = {'perc_pop_econ_ativa' :'{:.2%}'}

# %% [markdown]
# Depois podemos executar o `.style.format()` em uma parte do `DataFrame` (ou todo ele se quiséssemos):

# %%
igm.sample(5).style.format(format_dict)

# %% [markdown]
# Se olharmos o `.info()`, veremos que `perc_pop_econ_ativa` ainda é numérico:

# %%
igm.info()

# %% [markdown]
# Podemos converter várias colunas ao mesmo tempo criando um dicionário com vários valores:

# %%
format_dict = {'perc_pop_econ_ativa' :'{:.0%}', 'taxa_empreendedorismo' :'{:.0%}'}

# %% [markdown]
# E podemos executar o `.style.format()` novamente

# %%
igm.sample(5).style.format(format_dict)

# %% [markdown]
# ## Bônus: Juntando DataFrames

# %% [markdown]
# Vamos importar uma segunda base de exemplos:

# %%
igf = pd.read_excel('../input/exemplo_2.xls', header=[0], skiprows=8, skip_footer=2)

# %% [markdown]
# Vamos observar como estão nossos dados:

# %%
igf

# %% [markdown]
# Vamos remover a primeira linha. Usamos o método `.copy()` para evitarmos avisos no futuro.

# %%
igf = igf[1:].copy()

# %% [markdown]
# Vamos renomear a coluna `Unnamed: 1':'Ranking Estadual`, para isso vamos usar o comando `rename()`:

# %%
igf.rename(columns={'Unnamed: 1':'Ranking Estadual'}, inplace=True)

# %% [markdown]
# Como não temos códigos em ambos os `DataFrames` com nomes de `df` e `igf`, vamos fazer a junção deles por meio dos nomes dos municípios, para isso vamos deixar o nome da coluna referente aos nomes dos municípios iguais nos 2 `DataFrames`.

# %%
igf.rename(columns={'Município':'mun'}, inplace=True)
df.rename(columns={'NOME DO MUNICÍPIO':'mun'}, inplace=True)

# %% [markdown]
# Vamos tentar juntar os `DataFrames` e ver o que acontece:

# %%
df.merge(igf)

# %% [markdown]
# O nosso `DataFrame` após o `merge()` ficou com 5526 linhas, o que significa que 44 munícipios não estão com nomes iguais entre os DataFrames

# %%
df.merge(igf).shape

# %% [markdown]
# O `DataFrame` chamado `df` tem 5570 munícipios e com 6 colunas:

# %%
df.shape

# %% [markdown]
# O `DataFrame` chamado `df` tem 5568 munícipios e com 10 colunas:

# %%
igf.shape

# %% [markdown]
# Engraçado, que temos 10 colunas em um `DataFrame` e 6 colunas em outro, mas o nosso resultado do merge é de 14 colunas, por que isso?

# %% [markdown]
# ## Retirando acentos e caracteres especiais:

# %% [markdown]
# Vamos criar uma coluna chamada `Munícipio` para guardar os nomes originais dos munícipios.

# %%
df['Município'] = df['mun']

# %% [markdown]
# Podemos usar o método `str.normalize...` para retirar os acentos e outros caracteres especiais:

# %%
igf['mun'] = igf['mun'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df['mun'] = df['mun'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %% [markdown]
# Podemos ver que ganhamos mais algumas conversões, mas ainda foram poucas.

# %%
df.merge(igf).shape

# %% [markdown]
# ## Retirando os espaços

# %% [markdown]
# Vamos usar o comando `str.replace(' ','')` para remover os espaços em branco dos munícipios

# %%
igf['mun'] = igf['mun'].str.replace(' ','')
df['mun'] = df['mun'].str.replace(' ','')

# %% [markdown]
# Podemos ver que ganhamos mais alguns itens no nosso merge, mas ainda falta um pouco:

# %%
df.merge(igf).shape

# %% [markdown]
# ## O Comando `isin()`:

# %% [markdown]
# Atráves do comando `isin()` conseguimos se os valores de uma coluna estão contidos em outra coluna. Com o `~` conseguimos saber quais os valores não estão contidos.

# %% [markdown]
# A seguir vamos selecionar os valores da coluna `mun` de `df` que não estão contidos na coluna `mun` de `igf`.

# %%
df_mun = df[~df.mun.isin(igf['mun'])]['mun'].values

# %% [markdown]
# A seguir vamos selecionar os valores da coluna `mun` de `igf` que não estão contidos na coluna `mun` de `df`.

# %%
igf_mun = igf[~igf.mun.isin(df['mun'])]['mun'].values

# %% [markdown]
# ## Comparando proximidade de strings:

# %% [markdown]
# Vamos importar o `SequenceMatcher` para compararmos dois textos e gerarmos um score de quão próximos eles são (1 é idêntico e 0 é nada similar).

# %%
from difflib import SequenceMatcher

# %% [markdown]
# Vamos testar todos os valores contidos nas variáveis `df_mun` e `igf_mun` para saber quais são os valores na coluna `mun` de cada `DataFrame` que mais se assemelham, e substituir esses valores caso eles tenham uma semelhança maior do que 80%.

# %%
for municipio_1 in df_mun:
    
    
    print(score, municipios_proximos)
    if score > 0.8:
        idx = igf[igf['mun']==municipios_proximos[1]].index[0]
        igf.at[idx, 'mun'] = municipios_proximos[0]

# %% [markdown]
# Vamos avaliar as diferenças que ainda restam:

# %%
df.merge(igf).shape

# %%
df[~df.mun.isin(igf.mun)]

# %%
igf[~igf.mun.isin(df.mun)]

# %% [markdown]
# ## O comando `.at[]`

# %% [markdown]
# Para substituirmos uma célula em específico é ideal usar o comando `.at[]`

# %%
igf.at[2911,'mun'] = 'EmbudasArtes'

# %% [markdown]
# Podemos conferir que a atualização foi efetuada de forma correta:

# %%
df[~df.mun.isin(igf.mun)]

# %%
igf[~igf.mun.isin(df.mun)]

# %% [markdown]
# Vamos terminar de substituir outros munícipios que façam sentido:

# %%
igf.at[4702, 'mun'] = 'SaoValerio'

# %%
igf.at[4962, 'mun'] = 'SaoVicentedoSerido'

# %% [markdown]
# Vamos avaliar as diferenças:

# %%
df[~df.mun.isin(igf.mun)]

# %%
igf[~igf.mun.isin(df.mun)]

# %% [markdown]
# Neste ponto as diferenças são mínimas, e a questão é realmente uma intervenção humana de caso a caso para decidir qual caminho vai ser dado para a junção entre tabelas.

# %%
df.merge(igf).shape
