# %% [markdown]
# <a href="https://colab.research.google.com/github/Patotricks15/Data-Science-and-Statistics/blob/master/Mortes_acidentes_transito_SP(2015-2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ACIDENTES FATAIS NO ESTADO DE SÃO PAULO (2015-2020)**

# %% [markdown]
# ![alt text](https://transformacoes.observatoriodasmetropoles.net.br/wp-content/uploads/2015/06/46dab725dcec21832ff6fc55e05fcea7_L.jpg)

# %% [markdown]
# # **INTRODUÇÃO**
#
# ---
#
# Muito se tem discutido acerca do problema da mobilidade urbana em SP. E nessa análise exploratória iremos explorar uma parte importante do assunto: **os acidentes fatais.**
#
# Você é um Profissional da área de dados contratado pelo Departamento Estadual de Trânsito de São Paulo.
#
# O órgão possui dados históricos de acidentes de trânsito fatais ocorridos no estado entre 2015 e 2020.
#
# A equipe técnica sabe que existem muitos acidentes, mas existe uma dificuldade: **Precisamos decidir onde e como concentrar nossos esforços para reduzir mortes no trânsito.**
#
# O problema é que o orçamento para campanhas educativas, fiscalização e intervenções de segurança é limitado.
#
# Portanto, não é possível simplesmente "melhorar o trânsito inteiro".
#
# A direção quer que a equipe de dados ajude a responder: **Quais padrões nos acidentes fatais podem ajudar o poder público a definir prioridades de intervenção?**

# %% [markdown]
# # **ANALISANDO OS DADOS**
#
# ---
# Limpeza e estruturação dos dados

# %% [markdown]
# O primeiro passo é importar as bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Depois chamamos os dados e visualizamos o conjunto de dados

# %%
df = pd.read_csv('acidentes_sp_clean.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('acidentes_sp_clean.csv')
#       2 df.head()
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ## Atividade: Investigando um problema social com dados
# Quando analisamos um problema social, devemos fazer muitas perguntas, porque geralmente são problemas complexos, resultantes de inúmeros fatores e que afetam diferentes grupos da população.
#
# Para um profissional de dados, o primeiro passo é entender os dados. Em seguida, é necessário formular perguntas que possam ser investigadas por meio deles. As respostas encontradas podem ajudar a compreender melhor o problema e apoiar decisões para resolvê-lo ou minimizá-lo.
#
# Sua missão: utilizando a base de dados sobre acidentes de trânsito fatais em São Paulo, investigue o problema por meio das etapas abaixo.
#
# 1. Conheça os dados: carregue a base, observe sua estrutura, identifique as variáveis disponíveis e verifique possíveis problemas nos dados.
#
# 2. Defina 4 perguntas: formule quatro perguntas que possam ser respondidas utilizando os dados disponíveis. As perguntas devem contribuir para compreender diferentes aspectos do problema.
#
# 3. Analise os dados: para cada pergunta, utilize código Python para realizar as análises necessárias. Escolha as tabelas, cálculos e visualizações que melhor ajudem a responder cada pergunta.
#
# 4. Responda às perguntas: após cada análise, escreva uma conclusão baseada nas evidências encontradas nos dados.
#
# Importante: não crie gráficos simplesmente para visualizar os dados. Cada análise deve ter uma finalidade: ajudar a responder uma pergunta sobre o problema.

# %% [markdown]
# ## 1.Conhecendo os dados
#
# Antes de começar a responder às perguntas sobre o problema, precisamos **conhecer os dados**.
#
# Explore a base utilizando alguns dos comandos abaixo. Você não precisa utilizar todos. O objetivo é descobrir **como os dados estão organizados, quais informações estão disponíveis e se existem problemas que precisam ser tratados**.
#
# ### Visualizar os dados
#
# Para observar as primeiras linhas da base:
#
# ```python
# df.head()
# ```
#
# Também podemos visualizar as últimas linhas:
#
# ```python
# df.tail()
# ```
#
# Para visualizar uma quantidade específica de linhas:
#
# ```python
# df.head(10)
# ```
#
# ### Descobrir o tamanho da base
#
# Quantas linhas e colunas existem?
#
# ```python
# df.shape
# ```
#
# ### Conhecer as colunas
#
# Quais informações estão disponíveis na base?
#
# ```python
# df.columns
# ```
#
# ### Observar informações gerais
#
# Esse comando apresenta informações importantes sobre a base, como os tipos das colunas e a quantidade de valores preenchidos:
#
# ```python
# df.info()
# ```
#
# ### Verificar valores ausentes
#
# Existem informações faltando?
#
# ```python
# df.isnull().sum()
# ```
#
# ### Verificar registros duplicados
#
# Existem linhas repetidas?
#
# ```python
# df.duplicated().sum()
# ```
#
# ### Observar os valores de uma coluna
#
# Escolha uma coluna da base e observe alguns de seus valores:
#
# ```python
# df["nome_da_coluna"].head()
# ```
#
# ### Contar os valores de uma coluna
#
# Quantas vezes cada categoria aparece?
#
# ```python
# df["nome_da_coluna"].value_counts()
# ```
#
# Para visualizar apenas os 10 valores mais frequentes:
#
# ```python
# df["nome_da_coluna"].value_counts().head(10)
# ```
#
# ### Obter estatísticas básicas
#
# Para conhecer algumas estatísticas das variáveis numéricas:
#
# ```python
# df.describe()
# ```
#
# Também podemos analisar uma coluna numérica específica:
#
# ```python
# df["nome_da_coluna"].describe()
# ```
#
# ### Fazer uma primeira investigação
#
# Agora que você já conhece melhor a base, comece a fazer perguntas aos dados.
#
# Por exemplo, podemos descobrir quais categorias aparecem com maior frequência:
#
# ```python
# df["nome_da_coluna"].value_counts()
# ```
#
# Podemos também representar essas informações em um gráfico:
#
# ```python
# df["nome_da_coluna"].value_counts().plot(kind="bar")
# plt.show()
# ```
#
# ### Pense como um profissional de dados
#
# Durante essa exploração, procure descobrir:
#
# * Quais informações estão disponíveis?
# * Quais variáveis parecem importantes para o problema?
# * Existem dados faltantes?
# * Existem registros duplicados?
# * Existem categorias que aparecem com muita frequência?
# * Existem diferenças entre grupos?
#
# **Importante:** neste momento, não tente responder às quatro perguntas da atividade. Primeiro, conheça os dados e pense em **quais perguntas podem ser investigadas utilizando essas informações**.

# %% [markdown]
# ## Defina suas 4 perguntas
#
# Agora que você conhece melhor os dados, chegou o momento de definir 4 perguntas que gostaria de investigar sobre os acidentes de trânsito fatais.
#
# Pense como um profissional de dados: que informações poderiam ajudar a compreender melhor esse problema e ajudar a guiar uma solução para minimizar o problema?
#
# As perguntas devem ser claras, relevantes e possíveis de responder utilizando os dados disponíveis. Evite perguntas que possam ser respondidas apenas com uma opinião. Cada pergunta deverá ser posteriormente investigada por meio de código e evidências encontradas nos dados.

# %% [markdown]
# # Pergunta 1:

# %% [markdown]
# # Pergunta 2:

# %% [markdown]
# # Pergunta 3:

# %% [markdown]
# # Pergunta 4:

# %% [markdown]
# # **Conclusões e Recomendações**
#
# Depois de investigar as quatro perguntas, reúna os principais resultados encontrados e procure construir uma visão geral sobre o problema.
#
# Na conclusão, explique o que os dados permitiram compreender, destacando os padrões e informações mais relevantes encontrados durante a análise.
#
# Em seguida, apresente recomendações baseadas nas evidências. Pense em ações que poderiam contribuir para compreender melhor o problema, reduzir sua ocorrência ou orientar a tomada de decisões.
#
# Lembre-se: uma boa recomendação deve estar relacionada aos resultados encontrados nos dados. Não basta dizer o que deveria ser feito, é necessário explicar quais evidências levaram você a essa recomendação.
#
# Por fim, reflita sobre as limitações da análise: o que os dados não permitiram responder? Que outras informações seriam necessárias para compreender melhor o problema?

# %% [markdown]
# # **Conclusões e Recomendações do seu estudo**
